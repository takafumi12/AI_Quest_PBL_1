# %%
import numpy as np
import pandas as pd
from pandas import DataFrame, Series
import matplotlib.pyplot as plt
import seaborn as sns
import lightgbm as lgb

from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import LabelEncoder

# 最大表示列数の指定（ここでは50列を指定）
pd.set_option("display.max_columns", 1000)
pd.set_option("display.max_rows", 1000)

import warnings
warnings.filterwarnings("ignore")

# %%
path = "../input/pickle/"

train = pd.read_pickle(path + "train.zip")

train = train[train["item_category_big"]==7].copy().reset_index(drop=True)

train_x = train.drop(["y"], axis=1)
train_y = train["y"]
test_x = pd.read_pickle(path + "test.zip")

train.drop("item_category_big", axis=1, inplace=True)

test_x = test_x[test_x["item_category_big"]==7].copy()

test_x.drop("item_category_big", axis=1, inplace=True)

# %%
train_x.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 109380 entries, 0 to 109379
# Data columns (total 11 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   year                   109380 non-null  int64
#  1   month                  109380 non-null  int64
#  2   shopID                 109380 non-null  int64
#  3   itemID                 109380 non-null  int64
#  4   item_categoryID        109380 non-null  int64
#  5   item_category_big      109380 non-null  int64
#  6   release_time           109380 non-null  float64
#  7   sale_last_month        109380 non-null  float64
#  8   item_price_last_month  109380 non-null  float64
#  9   item_price_difference  109380 non-null  int64
#  10  item_price             109380 non-null  float64
# dtypes: float64(4), int64(7)
# memory usage: 9.2 MB

# %%
test_x.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 936 entries, 306 to 2987
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   itemID                 936 non-null    int64
#  1   shopID                 936 non-null    int64
#  2   item_categoryID        936 non-null    int64
#  3   month                  936 non-null    int64
#  4   year                   936 non-null    int64
#  5   release_time           936 non-null    int64
#  6   sale_last_month        936 non-null    float64
#  7   item_price_last_month  936 non-null    float64
#  8   item_price_difference  936 non-null    float64
#  9   item_price             936 non-null    float64
# dtypes: float64(4), int64(6)
# memory usage: 80.4 KB

# %%
train_x.index
# Out:
# RangeIndex(start=0, stop=109380, step=1)

# %%
years = [2018] * 6 + [2019] * 9
months = list(range(7, 13)) + list(range(1, 10))

# %%
month_list = list(range(1, 7))
year_list = [2017] + [2018]

scores = []

# custom function to run light gbm model
def run_lgb(train_X, train_y, val_X, val_y, x_test):
    params = {"objective" : "regression", 
              "metric" : "rmse", 
              "n_estimators":20000, 
              "early_stopping_rounds":200,
              "num_leaves" : 31, 
              "learning_rate" : 0.01, 
              "bagging_fraction" : 0.7,
              "bagging_seed" : 0, 
              "num_threads" : 4,
              "colsample_bytree" : 0.7,
              'max_depth': 5
             }
    
    lgtrain = lgb.Dataset(tr_x, tr_y)
    lgval = lgb.Dataset(va_x, va_y)
    model = lgb.train(params, lgtrain, 
                      valid_sets=[lgtrain, lgval], 
                      verbose_eval=1000)
    
    pred_test_y = model.predict(x_test, num_iteration=model.best_iteration)
    return pred_test_y, model

for year, month in zip(years, months):
    if year == 2019 and len(year_list) == 2:
        year_list.append(year)
    
    month_list.append(month)
    
    if month == 12:
        year += 1
        month = 1
    
    tr_x = train_x[(train_x["year"].isin(year_list))&(train_x["month"].isin(month_list))]
    va_x = train_x[(train_x["year"] == year)&(train_x["month"] == month)]
    tr_y, va_y = train_y.iloc[tr_x.index], train_y.iloc[va_x.index]
    
    # Training the model
    pred_test, model = run_lgb(tr_x, tr_y, va_x, va_y, test_x)
    
    # バリデーションデータでのスコアの確認
    va_pred = model.predict(va_x)
    score = np.sqrt(mean_squared_error(va_y, va_pred))
    
    scores.append(score)
# Out:
# Training until validation scores don't improve for 200 rounds
# [1000]	training's rmse: 1.25352	valid_1's rmse: 1.18575
# [2000]	training's rmse: 1.15403	valid_1's rmse: 1.1311
# [3000]	training's rmse: 1.1054	valid_1's rmse: 1.09718
# [4000]	training's rmse: 1.07742	valid_1's rmse: 1.06874
# [5000]	training's rmse: 1.04639	valid_1's rmse: 1.03741
# [6000]	training's rmse: 1.02562	valid_1's rmse: 1.01636
# [7000]	training's rmse: 1.01026	valid_1's rmse: 1.00288
# [8000]	training's rmse: 0.997235	valid_1's rmse: 0.98838
# [9000]	training's rmse: 0.98451	valid_1's rmse: 0.976594
# [10000]	training's rmse: 0.974278	valid_1's rmse: 0.967264
# [11000]	training's rmse: 0.964618	valid_1's rmse: 0.957876
# [12000]	training's rmse: 0.955941	valid_1's rmse: 0.949311
# [13000]	training's rmse: 0.949551	valid_1's rmse: 0.941634
# [14000]	training's rmse: 0.943476	valid_1's rmse: 0.933799
# [15000]	training's rmse: 0.938864	valid_1's rmse: 0.927575
# [16000]	training's rmse: 0.930095	valid_1's rmse: 0.92112
# [17000]	training's rmse: 0.922766	valid_1's rmse: 0.913762
# [18000]	training's rmse: 0.918495	valid_1's rmse: 0.908571
# [19000]	training's rmse: 0.91452	valid_1's rmse: 0.904479
# [20000]	training's rmse: 0.908801	valid_1's rmse: 0.899402
# Did not meet early stopping. Best iteration is:
# [20000]	training's rmse: 0.908801	valid_1's rmse: 0.899402
# Training until validation scores don't improve for 200 rounds
# [1000]	training's rmse: 1.24993	valid_1's rmse: 1.15382
# [2000]	training's rmse: 1.15553	valid_1's rmse: 1.09351
# [3000]	training's rmse: 1.10595	valid_1's rmse: 1.06025
# [4000]	training's rmse: 1.06915	valid_1's rmse: 1.03146
# [5000]	training's rmse: 1.04588	valid_1's rmse: 1.01005
# [6000]	training's rmse: 1.02607	valid_1's rmse: 0.992093
# [7000]	training's rmse: 1.00546	valid_1's rmse: 0.97006
# [8000]	training's rmse: 0.990033	valid_1's rmse: 0.956986
# [9000]	training's rmse: 0.976668	valid_1's rmse: 0.94455
# [10000]	training's rmse: 0.967045	valid_1's rmse: 0.932546
# [11000]	training's rmse: 0.957433	valid_1's rmse: 0.921348
# [12000]	training's rmse: 0.947129	valid_1's rmse: 0.91309
# [13000]	training's rmse: 0.937232	valid_1's rmse: 0.903824
# [14000]	training's rmse: 0.929251	valid_1's rmse: 0.894598
# [15000]	training's rmse: 0.922872	valid_1's rmse: 0.887924
# [16000]	training's rmse: 0.915687	valid_1's rmse: 0.879858
# [17000]	training's rmse: 0.908723	valid_1's rmse: 0.873927
# [18000]	training's rmse: 0.90136	valid_1's rmse: 0.867156
# [19000]	training's rmse: 0.895255	valid_1's rmse: 0.860638
# [20000]	training's rmse: 0.889376	valid_1's rmse: 0.853662
# Did not meet early stopping. Best iteration is:
# [20000]	training's rmse: 0.889376	valid_1's rmse: 0.853662
# Training until validation scores don't improve for 200 rounds
# [1000]	training's rmse: 1.23073	valid_1's rmse: 1.00403
# [2000]	training's rmse: 1.12842	valid_1's rmse: 0.953591
# [3000]	training's rmse: 1.08439	valid_1's rmse: 0.920485
# [4000]	training's rmse: 1.05749	valid_1's rmse: 0.899727
# [5000]	training's rmse: 1.03188	valid_1's rmse: 0.885017
# [6000]	training's rmse: 1.01171	valid_1's rmse: 0.872764
# [7000]	training's rmse: 0.996749	valid_1's rmse: 0.864108
# [8000]	training's rmse: 0.981346	valid_1's rmse: 0.851396
# [9000]	training's rmse: 0.970006	valid_1's rmse: 0.843501
# [10000]	training's rmse: 0.960665	valid_1's rmse: 0.834644
# [11000]	training's rmse: 0.951191	valid_1's rmse: 0.826466
# [12000]	training's rmse: 0.942396	valid_1's rmse: 0.818051
# [13000]	training's rmse: 0.935057	valid_1's rmse: 0.812471
# [14000]	training's rmse: 0.927116	valid_1's rmse: 0.803901
# [15000]	training's rmse: 0.917875	valid_1's rmse: 0.797754
# [16000]	training's rmse: 0.911986	valid_1's rmse: 0.792947
# [17000]	training's rmse: 0.903847	valid_1's rmse: 0.787463
# [18000]	training's rmse: 0.896231	valid_1's rmse: 0.780762
# [19000]	training's rmse: 0.889374	valid_1's rmse: 0.774416
# [20000]	training's rmse: 0.882804	valid_1's rmse: 0.769012
# Did not meet early stopping. Best iteration is:
# [20000]	training's rmse: 0.882804	valid_1's rmse: 0.769012
# Training until validation scores don't improve for 200 rounds
# [1000]	training's rmse: 1.24702	valid_1's rmse: 1.23713
# [2000]	training's rmse: 1.15854	valid_1's rmse: 1.1842
# [3000]	training's rmse: 1.10939	valid_1's rmse: 1.15588
# [4000]	training's rmse: 1.07772	valid_1's rmse: 1.13524
# [5000]	training's rmse: 1.05776	valid_1's rmse: 1.11698
# [6000]	training's rmse: 1.04306	valid_1's rmse: 1.10328
# [7000]	training's rmse: 1.02742	valid_1's rmse: 1.08973
# [8000]	training's rmse: 1.01641	valid_1's rmse: 1.08071
# [9000]	training's rmse: 1.00312	valid_1's rmse: 1.06755
# [10000]	training's rmse: 0.991311	valid_1's rmse: 1.05244
# [11000]	training's rmse: 0.983511	valid_1's rmse: 1.04516
# [12000]	training's rmse: 0.975569	valid_1's rmse: 1.03687
# [13000]	training's rmse: 0.967148	valid_1's rmse: 1.02908
# [14000]	training's rmse: 0.959234	valid_1's rmse: 1.02365
# [15000]	training's rmse: 0.951114	valid_1's rmse: 1.01703
# [16000]	training's rmse: 0.944649	valid_1's rmse: 1.00914
# [17000]	training's rmse: 0.938721	valid_1's rmse: 1.00213
# [18000]	training's rmse: 0.933052	valid_1's rmse: 0.994238
# [19000]	training's rmse: 0.927387	valid_1's rmse: 0.986089
# [20000]	training's rmse: 0.921262	valid_1's rmse: 0.978659
# Did not meet early stopping. Best iteration is:
# [20000]	training's rmse: 0.921262	valid_1's rmse: 0.978659
# Training until validation scores don't improve for 200 rounds
# [1000]	training's rmse: 1.26216	valid_1's rmse: 1.35221
# [2000]	training's rmse: 1.17695	valid_1's rmse: 1.27721
# [3000]	training's rmse: 1.13433	valid_1's rmse: 1.23541
# [4000]	training's rmse: 1.10776	valid_1's rmse: 1.20494
# [5000]	training's rmse: 1.08653	valid_1's rmse: 1.17829
# [6000]	training's rmse: 1.06848	valid_1's rmse: 1.16036
# [7000]	training's rmse: 1.05419	valid_1's rmse: 1.14478
# [8000]	training's rmse: 1.04175	valid_1's rmse: 1.12934
# [9000]	training's rmse: 1.02781	valid_1's rmse: 1.1145
# [10000]	training's rmse: 1.01778	valid_1's rmse: 1.10382
# [11000]	training's rmse: 1.00879	valid_1's rmse: 1.09573
# [12000]	training's rmse: 0.999281	valid_1's rmse: 1.08702
# [13000]	training's rmse: 0.992851	valid_1's rmse: 1.08001
# [14000]	training's rmse: 0.983144	valid_1's rmse: 1.06808
# [15000]	training's rmse: 0.975675	valid_1's rmse: 1.05865
# [16000]	training's rmse: 0.969321	valid_1's rmse: 1.04999
# [17000]	training's rmse: 0.962501	valid_1's rmse: 1.04159
# [18000]	training's rmse: 0.956207	valid_1's rmse: 1.03514
# [19000]	training's rmse: 0.948651	valid_1's rmse: 1.0274
# [20000]	training's rmse: 0.944306	valid_1's rmse: 1.02169
# Did not meet early stopping. Best iteration is:
# [20000]	training's rmse: 0.944306	valid_1's rmse: 1.02169
# Training until validation scores don't improve for 200 rounds
# Early stopping, best iteration is:
# [579]	training's rmse: 1.40977	valid_1's rmse: 1.20195
# Training until validation scores don't improve for 200 rounds
# [1000]	training's rmse: 1.36311	valid_1's rmse: 1.10615
# [2000]	training's rmse: 1.30076	valid_1's rmse: 1.06271
# [3000]	training's rmse: 1.26255	valid_1's rmse: 1.03703
# [4000]	training's rmse: 1.23601	valid_1's rmse: 1.02028
# [5000]	training's rmse: 1.21744	valid_1's rmse: 1.00469
# [6000]	training's rmse: 1.20165	valid_1's rmse: 0.993081
# [7000]	training's rmse: 1.1859	valid_1's rmse: 0.982673
# [8000]	training's rmse: 1.16999	valid_1's rmse: 0.972657
# [9000]	training's rmse: 1.15788	valid_1's rmse: 0.965494
# [10000]	training's rmse: 1.14814	valid_1's rmse: 0.957724
# [11000]	training's rmse: 1.13882	valid_1's rmse: 0.950571
# [12000]	training's rmse: 1.13018	valid_1's rmse: 0.943485
# [13000]	training's rmse: 1.12253	valid_1's rmse: 0.937469
# [14000]	training's rmse: 1.11649	valid_1's rmse: 0.931601
# [15000]	training's rmse: 1.10927	valid_1's rmse: 0.925461
# [16000]	training's rmse: 1.10296	valid_1's rmse: 0.92005
# [17000]	training's rmse: 1.0974	valid_1's rmse: 0.915024
# [18000]	training's rmse: 1.09169	valid_1's rmse: 0.908994
# [19000]	training's rmse: 1.0842	valid_1's rmse: 0.902127
# [20000]	training's rmse: 1.0781	valid_1's rmse: 0.898469
# Did not meet early stopping. Best iteration is:
# [20000]	training's rmse: 1.0781	valid_1's rmse: 0.898469
# Training until validation scores don't improve for 200 rounds
# [1000]	training's rmse: 1.36311	valid_1's rmse: 0.956317
# [2000]	training's rmse: 1.30076	valid_1's rmse: 0.925265
# [3000]	training's rmse: 1.26255	valid_1's rmse: 0.900951
# [4000]	training's rmse: 1.23601	valid_1's rmse: 0.885521
# [5000]	training's rmse: 1.21744	valid_1's rmse: 0.875698
# [6000]	training's rmse: 1.20165	valid_1's rmse: 0.864006
# [7000]	training's rmse: 1.1859	valid_1's rmse: 0.853353
# [8000]	training's rmse: 1.16999	valid_1's rmse: 0.845807
# [9000]	training's rmse: 1.15788	valid_1's rmse: 0.837273
# [10000]	training's rmse: 1.14814	valid_1's rmse: 0.831019
# [11000]	training's rmse: 1.13882	valid_1's rmse: 0.823665
# [12000]	training's rmse: 1.13018	valid_1's rmse: 0.816731
# [13000]	training's rmse: 1.12253	valid_1's rmse: 0.811689
# [14000]	training's rmse: 1.11649	valid_1's rmse: 0.806321
# [15000]	training's rmse: 1.10927	valid_1's rmse: 0.801175
# [16000]	training's rmse: 1.10296	valid_1's rmse: 0.796404
# [17000]	training's rmse: 1.0974	valid_1's rmse: 0.792359
# [18000]	training's rmse: 1.09169	valid_1's rmse: 0.788111
# [19000]	training's rmse: 1.0842	valid_1's rmse: 0.784526
# [20000]	training's rmse: 1.0781	valid_1's rmse: 0.780476
# Did not meet early stopping. Best iteration is:
# [20000]	training's rmse: 1.0781	valid_1's rmse: 0.780476
# Training until validation scores don't improve for 200 rounds
# [1000]	training's rmse: 1.36311	valid_1's rmse: 1.34786
# [2000]	training's rmse: 1.30076	valid_1's rmse: 1.265
# [3000]	training's rmse: 1.26255	valid_1's rmse: 1.22092
# [4000]	training's rmse: 1.23601	valid_1's rmse: 1.18907
# [5000]	training's rmse: 1.21744	valid_1's rmse: 1.16422
# [6000]	training's rmse: 1.20165	valid_1's rmse: 1.14226
# [7000]	training's rmse: 1.1859	valid_1's rmse: 1.12594
# [8000]	training's rmse: 1.16999	valid_1's rmse: 1.11293
# [9000]	training's rmse: 1.15788	valid_1's rmse: 1.09603
# [10000]	training's rmse: 1.14814	valid_1's rmse: 1.08923
# [11000]	training's rmse: 1.13882	valid_1's rmse: 1.08008
# [12000]	training's rmse: 1.13018	valid_1's rmse: 1.07275
# [13000]	training's rmse: 1.12253	valid_1's rmse: 1.06609
# [14000]	training's rmse: 1.11649	valid_1's rmse: 1.05883
# [15000]	training's rmse: 1.10927	valid_1's rmse: 1.05213
# [16000]	training's rmse: 1.10296	valid_1's rmse: 1.04607
# [17000]	training's rmse: 1.0974	valid_1's rmse: 1.04182
# [18000]	training's rmse: 1.09169	valid_1's rmse: 1.03625
# [19000]	training's rmse: 1.0842	valid_1's rmse: 1.03135
# [20000]	training's rmse: 1.0781	valid_1's rmse: 1.02689
# Did not meet early stopping. Best iteration is:
# [20000]	training's rmse: 1.0781	valid_1's rmse: 1.02689
# Training until validation scores don't improve for 200 rounds
# [1000]	training's rmse: 1.36311	valid_1's rmse: 1.26729
# [2000]	training's rmse: 1.30076	valid_1's rmse: 1.19251
# [3000]	training's rmse: 1.26255	valid_1's rmse: 1.16928
# [4000]	training's rmse: 1.23601	valid_1's rmse: 1.15444
# [5000]	training's rmse: 1.21744	valid_1's rmse: 1.14174
# [6000]	training's rmse: 1.20165	valid_1's rmse: 1.12629
# [7000]	training's rmse: 1.1859	valid_1's rmse: 1.11258
# [8000]	training's rmse: 1.16999	valid_1's rmse: 1.10104
# [9000]	training's rmse: 1.15788	valid_1's rmse: 1.08077
# [10000]	training's rmse: 1.14814	valid_1's rmse: 1.0726
# [11000]	training's rmse: 1.13882	valid_1's rmse: 1.0625
# [12000]	training's rmse: 1.13018	valid_1's rmse: 1.05183
# [13000]	training's rmse: 1.12253	valid_1's rmse: 1.04584
# [14000]	training's rmse: 1.11649	valid_1's rmse: 1.03883
# [15000]	training's rmse: 1.10927	valid_1's rmse: 1.03292
# [16000]	training's rmse: 1.10296	valid_1's rmse: 1.02756
# [17000]	training's rmse: 1.0974	valid_1's rmse: 1.02187
# [18000]	training's rmse: 1.09169	valid_1's rmse: 1.01257
# [19000]	training's rmse: 1.0842	valid_1's rmse: 1.00502
# [20000]	training's rmse: 1.0781	valid_1's rmse: 1.00122
# Did not meet early stopping. Best iteration is:
# [20000]	training's rmse: 1.0781	valid_1's rmse: 1.00122
# Training until validation scores don't improve for 200 rounds
# [1000]	training's rmse: 1.36311	valid_1's rmse: 1.42145
# [2000]	training's rmse: 1.30076	valid_1's rmse: 1.36419
# [3000]	training's rmse: 1.26255	valid_1's rmse: 1.3398
# [4000]	training's rmse: 1.23601	valid_1's rmse: 1.31613
# [5000]	training's rmse: 1.21744	valid_1's rmse: 1.29885
# [6000]	training's rmse: 1.20165	valid_1's rmse: 1.28218
# [7000]	training's rmse: 1.1859	valid_1's rmse: 1.27192
# [8000]	training's rmse: 1.16999	valid_1's rmse: 1.26158
# [9000]	training's rmse: 1.15788	valid_1's rmse: 1.24759
# [10000]	training's rmse: 1.14814	valid_1's rmse: 1.23433
# [11000]	training's rmse: 1.13882	valid_1's rmse: 1.22558
# [12000]	training's rmse: 1.13018	valid_1's rmse: 1.21677
# [13000]	training's rmse: 1.12253	valid_1's rmse: 1.20875
# [14000]	training's rmse: 1.11649	valid_1's rmse: 1.20196
# [15000]	training's rmse: 1.10927	valid_1's rmse: 1.19501
# [16000]	training's rmse: 1.10296	valid_1's rmse: 1.18824
# [17000]	training's rmse: 1.0974	valid_1's rmse: 1.18251
# [18000]	training's rmse: 1.09169	valid_1's rmse: 1.17552
# [19000]	training's rmse: 1.0842	valid_1's rmse: 1.16785
# [20000]	training's rmse: 1.0781	valid_1's rmse: 1.16203
# Did not meet early stopping. Best iteration is:
# [20000]	training's rmse: 1.0781	valid_1's rmse: 1.16203
# Training until validation scores don't improve for 200 rounds
# [1000]	training's rmse: 1.36311	valid_1's rmse: 1.68785
# [2000]	training's rmse: 1.30076	valid_1's rmse: 1.62357
# [3000]	training's rmse: 1.26255	valid_1's rmse: 1.58653
# [4000]	training's rmse: 1.23601	valid_1's rmse: 1.54041
# [5000]	training's rmse: 1.21744	valid_1's rmse: 1.51131
# [6000]	training's rmse: 1.20165	valid_1's rmse: 1.48367
# [7000]	training's rmse: 1.1859	valid_1's rmse: 1.4702
# [8000]	training's rmse: 1.16999	valid_1's rmse: 1.45522
# [9000]	training's rmse: 1.15788	valid_1's rmse: 1.44336
# [10000]	training's rmse: 1.14814	valid_1's rmse: 1.42236
# [11000]	training's rmse: 1.13882	valid_1's rmse: 1.41304
# [12000]	training's rmse: 1.13018	valid_1's rmse: 1.40532
# [13000]	training's rmse: 1.12253	valid_1's rmse: 1.39477
# [14000]	training's rmse: 1.11649	valid_1's rmse: 1.38776
# [15000]	training's rmse: 1.10927	valid_1's rmse: 1.37973
# [16000]	training's rmse: 1.10296	valid_1's rmse: 1.37111
# [17000]	training's rmse: 1.0974	valid_1's rmse: 1.36386
# [18000]	training's rmse: 1.09169	valid_1's rmse: 1.35521
# [19000]	training's rmse: 1.0842	valid_1's rmse: 1.34184
# [20000]	training's rmse: 1.0781	valid_1's rmse: 1.33597
# Did not meet early stopping. Best iteration is:
# [20000]	training's rmse: 1.0781	valid_1's rmse: 1.33597
# Training until validation scores don't improve for 200 rounds
# [1000]	training's rmse: 1.36311	valid_1's rmse: 1.72513
# [2000]	training's rmse: 1.30076	valid_1's rmse: 1.67129
# [3000]	training's rmse: 1.26255	valid_1's rmse: 1.636
# [4000]	training's rmse: 1.23601	valid_1's rmse: 1.59849
# [5000]	training's rmse: 1.21744	valid_1's rmse: 1.5761
# [6000]	training's rmse: 1.20165	valid_1's rmse: 1.55644
# [7000]	training's rmse: 1.1859	valid_1's rmse: 1.54361
# [8000]	training's rmse: 1.16999	valid_1's rmse: 1.51665
# [9000]	training's rmse: 1.15788	valid_1's rmse: 1.50554
# [10000]	training's rmse: 1.14814	valid_1's rmse: 1.49279
# [11000]	training's rmse: 1.13882	valid_1's rmse: 1.48118
# [12000]	training's rmse: 1.13018	valid_1's rmse: 1.47407
# [13000]	training's rmse: 1.12253	valid_1's rmse: 1.4651
# [14000]	training's rmse: 1.11649	valid_1's rmse: 1.45899
# [15000]	training's rmse: 1.10927	valid_1's rmse: 1.44882
# [16000]	training's rmse: 1.10296	valid_1's rmse: 1.44221
# [17000]	training's rmse: 1.0974	valid_1's rmse: 1.43604
# [18000]	training's rmse: 1.09169	valid_1's rmse: 1.42977
# [19000]	training's rmse: 1.0842	valid_1's rmse: 1.42076
# [20000]	training's rmse: 1.0781	valid_1's rmse: 1.41219
# Did not meet early stopping. Best iteration is:
# [20000]	training's rmse: 1.0781	valid_1's rmse: 1.41219
# Training until validation scores don't improve for 200 rounds
# [1000]	training's rmse: 1.36311	valid_1's rmse: 1.42456
# [2000]	training's rmse: 1.30076	valid_1's rmse: 1.3655
# [3000]	training's rmse: 1.26255	valid_1's rmse: 1.31978
# [4000]	training's rmse: 1.23601	valid_1's rmse: 1.29432
# [5000]	training's rmse: 1.21744	valid_1's rmse: 1.27868
# [6000]	training's rmse: 1.20165	valid_1's rmse: 1.26688
# [7000]	training's rmse: 1.1859	valid_1's rmse: 1.25591
# [8000]	training's rmse: 1.16999	valid_1's rmse: 1.23307
# [9000]	training's rmse: 1.15788	valid_1's rmse: 1.22251
# [10000]	training's rmse: 1.14814	valid_1's rmse: 1.20753
# [11000]	training's rmse: 1.13882	valid_1's rmse: 1.19608
# [12000]	training's rmse: 1.13018	valid_1's rmse: 1.19066
# [13000]	training's rmse: 1.12253	valid_1's rmse: 1.18432
# [14000]	training's rmse: 1.11649	valid_1's rmse: 1.17863
# [15000]	training's rmse: 1.10927	valid_1's rmse: 1.16663
# [16000]	training's rmse: 1.10296	valid_1's rmse: 1.15925
# [17000]	training's rmse: 1.0974	valid_1's rmse: 1.15497
# [18000]	training's rmse: 1.09169	valid_1's rmse: 1.14972
# [19000]	training's rmse: 1.0842	valid_1's rmse: 1.14506
# [20000]	training's rmse: 1.0781	valid_1's rmse: 1.13947
# Did not meet early stopping. Best iteration is:
# [20000]	training's rmse: 1.0781	valid_1's rmse: 1.13947
# Training until validation scores don't improve for 200 rounds
# [1000]	training's rmse: 1.36311	valid_1's rmse: 1.0707
# [2000]	training's rmse: 1.30076	valid_1's rmse: 1.03012
# [3000]	training's rmse: 1.26255	valid_1's rmse: 1.0035
# [4000]	training's rmse: 1.23601	valid_1's rmse: 0.985046
# [5000]	training's rmse: 1.21744	valid_1's rmse: 0.97057
# [6000]	training's rmse: 1.20165	valid_1's rmse: 0.962485
# [7000]	training's rmse: 1.1859	valid_1's rmse: 0.951566
# [8000]	training's rmse: 1.16999	valid_1's rmse: 0.937073
# [9000]	training's rmse: 1.15788	valid_1's rmse: 0.929693
# [10000]	training's rmse: 1.14814	valid_1's rmse: 0.922792
# [11000]	training's rmse: 1.13882	valid_1's rmse: 0.917184
# [12000]	training's rmse: 1.13018	valid_1's rmse: 0.910815
# [13000]	training's rmse: 1.12253	valid_1's rmse: 0.90563
# [14000]	training's rmse: 1.11649	valid_1's rmse: 0.900445
# [15000]	training's rmse: 1.10927	valid_1's rmse: 0.896372
# [16000]	training's rmse: 1.10296	valid_1's rmse: 0.89193
# [17000]	training's rmse: 1.0974	valid_1's rmse: 0.888098
# [18000]	training's rmse: 1.09169	valid_1's rmse: 0.884079
# [19000]	training's rmse: 1.0842	valid_1's rmse: 0.878879
# [20000]	training's rmse: 1.0781	valid_1's rmse: 0.876012
# Did not meet early stopping. Best iteration is:
# [20000]	training's rmse: 1.0781	valid_1's rmse: 0.876012

# %%
scores
# Out:
# [0.8994019074470937,
#  0.8536623699337109,
#  0.7690119801532859,
#  0.9786591668252524,
#  1.0216943239205603,
#  1.2019471335578538,
#  0.898469274424511,
#  0.7804761129905402,
#  1.0268891354666343,
#  1.0012170611590323,
#  1.1620344789136503,
#  1.3359671308445502,
#  1.412193421255369,
#  1.1394696701551368,
#  0.8760122529992501]

# %%
# 予測
test_x["y"] = model.predict(test_x)

# %%
test_x.to_pickle('../input/pickle/test_music.zip')

# %%
# path = "../submission/"

# submission = pd.read_csv(path + "sample_submission.csv", header=None)

# submission.iloc[:,[1]] = pred
# submission.head()

# %%
# submission.to_csv(path + "submission.csv", index=False, header=None)

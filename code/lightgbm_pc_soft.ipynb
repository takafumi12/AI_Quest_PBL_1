# %%
import numpy as np
import pandas as pd
from pandas import DataFrame, Series
import matplotlib.pyplot as plt
import seaborn as sns
import lightgbm as lgb

from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import LabelEncoder

# 最大表示列数の指定（ここでは50列を指定）
pd.set_option("display.max_columns", 1000)
pd.set_option("display.max_rows", 1000)

import warnings
warnings.filterwarnings("ignore")

# %%
path = "../input/pickle/"

train = pd.read_pickle(path + "train.zip")

train = train[train["item_category_big"].isin([0,1])].copy().reset_index(drop=True)

train_x = train.drop(["y"], axis=1)
train_y = train["y"]
test_x = pd.read_pickle(path + "test.zip")

test_x = test_x[test_x["item_category_big"].isin([0,1])].copy()

test_x.drop("item_category_big", axis=1, inplace=True)

# %%
train_x.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42474 entries, 0 to 42473
# Data columns (total 11 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   year                   42474 non-null  int64
#  1   month                  42474 non-null  int64
#  2   shopID                 42474 non-null  int64
#  3   itemID                 42474 non-null  int64
#  4   item_categoryID        42474 non-null  int64
#  5   item_category_big      42474 non-null  int64
#  6   release_time           42474 non-null  float64
#  7   sale_last_month        42474 non-null  float64
#  8   item_price_last_month  42474 non-null  float64
#  9   item_price_difference  42474 non-null  int64
#  10  item_price             42474 non-null  float64
# dtypes: float64(4), int64(7)
# memory usage: 3.6 MB

# %%
test_x.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 72 entries, 270 to 1763
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   itemID                 72 non-null     int64
#  1   shopID                 72 non-null     int64
#  2   item_categoryID        72 non-null     int64
#  3   month                  72 non-null     int64
#  4   year                   72 non-null     int64
#  5   release_time           72 non-null     int64
#  6   sale_last_month        72 non-null     float64
#  7   item_price_last_month  72 non-null     float64
#  8   item_price_difference  72 non-null     float64
#  9   item_price             72 non-null     float64
# dtypes: float64(4), int64(6)
# memory usage: 6.2 KB

# %%
train_x.index
# Out:
# RangeIndex(start=0, stop=42474, step=1)

# %%
years = [2018] * 6 + [2019] * 9
months = list(range(7, 13)) + list(range(1, 10))

# %%
month_list = list(range(1, 7))
year_list = [2017] + [2018]

scores = []

# custom function to run light gbm model
def run_lgb(train_X, train_y, val_X, val_y, x_test):
    params = {"objective" : "regression", 
              "metric" : "rmse", 
              "n_estimators":20000, 
              "early_stopping_rounds":200,
              "num_leaves" : 31, 
              "learning_rate" : 0.01, 
              "bagging_fraction" : 0.7,
              "bagging_seed" : 0, 
              "num_threads" : 4,
              "colsample_bytree" : 0.7,
              'max_depth': 5
             }
    
    lgtrain = lgb.Dataset(tr_x, tr_y)
    lgval = lgb.Dataset(va_x, va_y)
    model = lgb.train(params, lgtrain, 
                      valid_sets=[lgtrain, lgval], 
                      verbose_eval=1000)
    
    pred_test_y = model.predict(x_test, num_iteration=model.best_iteration)
    return pred_test_y, model

for year, month in zip(years, months):
    if year == 2019 and len(year_list) == 2:
        year_list.append(year)
    
    month_list.append(month)
    
    if month == 12:
        year += 1
        month = 1
    
    tr_x = train_x[(train_x["year"].isin(year_list))&(train_x["month"].isin(month_list))]
    va_x = train_x[(train_x["year"] == year)&(train_x["month"] == month)]
    tr_y, va_y = train_y.iloc[tr_x.index], train_y.iloc[va_x.index]
    
    # Training the model
    pred_test, model = run_lgb(tr_x, tr_y, va_x, va_y, test_x)
    
    # バリデーションデータでのスコアの確認
    va_pred = model.predict(va_x)
    score = np.sqrt(mean_squared_error(va_y, va_pred))
    
    scores.append(score)
# Out:
# Training until validation scores don't improve for 200 rounds
# [1000]	training's rmse: 5.19523	valid_1's rmse: 4.33309
# [2000]	training's rmse: 4.41896	valid_1's rmse: 3.54778
# [3000]	training's rmse: 4.02905	valid_1's rmse: 3.16096
# [4000]	training's rmse: 3.82238	valid_1's rmse: 2.98206
# [5000]	training's rmse: 3.64267	valid_1's rmse: 2.81925
# [6000]	training's rmse: 3.50066	valid_1's rmse: 2.72192
# [7000]	training's rmse: 3.35581	valid_1's rmse: 2.63861
# [8000]	training's rmse: 3.22608	valid_1's rmse: 2.57083
# [9000]	training's rmse: 3.12894	valid_1's rmse: 2.50479
# [10000]	training's rmse: 3.03403	valid_1's rmse: 2.4538
# [11000]	training's rmse: 2.92685	valid_1's rmse: 2.37192
# [12000]	training's rmse: 2.84491	valid_1's rmse: 2.30287
# [13000]	training's rmse: 2.7814	valid_1's rmse: 2.25458
# [14000]	training's rmse: 2.71063	valid_1's rmse: 2.21495
# [15000]	training's rmse: 2.64613	valid_1's rmse: 2.17586
# [16000]	training's rmse: 2.59666	valid_1's rmse: 2.13109
# [17000]	training's rmse: 2.54124	valid_1's rmse: 2.09143
# [18000]	training's rmse: 2.4921	valid_1's rmse: 2.04708
# [19000]	training's rmse: 2.45408	valid_1's rmse: 2.01921
# [20000]	training's rmse: 2.41495	valid_1's rmse: 1.99002
# Did not meet early stopping. Best iteration is:
# [20000]	training's rmse: 2.41495	valid_1's rmse: 1.99002
# Training until validation scores don't improve for 200 rounds
# [1000]	training's rmse: 5.17616	valid_1's rmse: 4.11876
# [2000]	training's rmse: 4.51432	valid_1's rmse: 3.54743
# [3000]	training's rmse: 4.19759	valid_1's rmse: 3.30021
# [4000]	training's rmse: 3.94364	valid_1's rmse: 3.12866
# [5000]	training's rmse: 3.76178	valid_1's rmse: 2.99024
# [6000]	training's rmse: 3.59442	valid_1's rmse: 2.8771
# [7000]	training's rmse: 3.46168	valid_1's rmse: 2.77469
# [8000]	training's rmse: 3.36047	valid_1's rmse: 2.69401
# [9000]	training's rmse: 3.25743	valid_1's rmse: 2.61761
# [10000]	training's rmse: 3.17373	valid_1's rmse: 2.56355
# [11000]	training's rmse: 3.09123	valid_1's rmse: 2.51434
# [12000]	training's rmse: 3.00061	valid_1's rmse: 2.46132
# [13000]	training's rmse: 2.90926	valid_1's rmse: 2.40961
# [14000]	training's rmse: 2.85411	valid_1's rmse: 2.36357
# [15000]	training's rmse: 2.78854	valid_1's rmse: 2.32521
# [16000]	training's rmse: 2.73096	valid_1's rmse: 2.27835
# [17000]	training's rmse: 2.67212	valid_1's rmse: 2.23729
# [18000]	training's rmse: 2.61712	valid_1's rmse: 2.20224
# [19000]	training's rmse: 2.5722	valid_1's rmse: 2.1559
# [20000]	training's rmse: 2.53332	valid_1's rmse: 2.12423
# Did not meet early stopping. Best iteration is:
# [20000]	training's rmse: 2.53332	valid_1's rmse: 2.12423
# Training until validation scores don't improve for 200 rounds
# [1000]	training's rmse: 5.18726	valid_1's rmse: 4.21144
# [2000]	training's rmse: 4.54026	valid_1's rmse: 3.67311
# [3000]	training's rmse: 4.21639	valid_1's rmse: 3.40736
# [4000]	training's rmse: 3.95954	valid_1's rmse: 3.21805
# [5000]	training's rmse: 3.7622	valid_1's rmse: 3.07725
# [6000]	training's rmse: 3.60061	valid_1's rmse: 2.96841
# [7000]	training's rmse: 3.47783	valid_1's rmse: 2.86682
# [8000]	training's rmse: 3.37318	valid_1's rmse: 2.80396
# [9000]	training's rmse: 3.26433	valid_1's rmse: 2.73118
# [10000]	training's rmse: 3.16522	valid_1's rmse: 2.65966
# [11000]	training's rmse: 3.08531	valid_1's rmse: 2.61065
# [12000]	training's rmse: 3.00752	valid_1's rmse: 2.55951
# [13000]	training's rmse: 2.94766	valid_1's rmse: 2.50515
# [14000]	training's rmse: 2.88131	valid_1's rmse: 2.46475
# [15000]	training's rmse: 2.81398	valid_1's rmse: 2.4027
# [16000]	training's rmse: 2.75953	valid_1's rmse: 2.35993
# [17000]	training's rmse: 2.70805	valid_1's rmse: 2.32066
# [18000]	training's rmse: 2.6582	valid_1's rmse: 2.28641
# [19000]	training's rmse: 2.60855	valid_1's rmse: 2.23376
# [20000]	training's rmse: 2.53335	valid_1's rmse: 2.19115
# Did not meet early stopping. Best iteration is:
# [20000]	training's rmse: 2.53335	valid_1's rmse: 2.19115
# Training until validation scores don't improve for 200 rounds
# [1000]	training's rmse: 5.44256	valid_1's rmse: 6.81665
# [2000]	training's rmse: 4.782	valid_1's rmse: 6.25914
# [3000]	training's rmse: 4.44615	valid_1's rmse: 5.95412
# [4000]	training's rmse: 4.20992	valid_1's rmse: 5.60586
# [5000]	training's rmse: 4.065	valid_1's rmse: 5.3484
# [6000]	training's rmse: 3.9175	valid_1's rmse: 5.09196
# [7000]	training's rmse: 3.78333	valid_1's rmse: 4.86877
# [8000]	training's rmse: 3.66299	valid_1's rmse: 4.66261
# [9000]	training's rmse: 3.56279	valid_1's rmse: 4.50328
# [10000]	training's rmse: 3.4534	valid_1's rmse: 4.33453
# [11000]	training's rmse: 3.35748	valid_1's rmse: 4.20613
# [12000]	training's rmse: 3.26547	valid_1's rmse: 4.05589
# [13000]	training's rmse: 3.17961	valid_1's rmse: 3.923
# [14000]	training's rmse: 3.10633	valid_1's rmse: 3.81401
# [15000]	training's rmse: 3.0554	valid_1's rmse: 3.70686
# [16000]	training's rmse: 2.99145	valid_1's rmse: 3.62016
# [17000]	training's rmse: 2.94008	valid_1's rmse: 3.5348
# [18000]	training's rmse: 2.89053	valid_1's rmse: 3.45289
# [19000]	training's rmse: 2.85123	valid_1's rmse: 3.37265
# [20000]	training's rmse: 2.81322	valid_1's rmse: 3.30196
# Did not meet early stopping. Best iteration is:
# [20000]	training's rmse: 2.81322	valid_1's rmse: 3.30196
# Training until validation scores don't improve for 200 rounds
# [1000]	training's rmse: 5.84807	valid_1's rmse: 8.12403
# [2000]	training's rmse: 5.09182	valid_1's rmse: 6.8126
# [3000]	training's rmse: 4.73975	valid_1's rmse: 6.23888
# [4000]	training's rmse: 4.48889	valid_1's rmse: 5.77968
# [5000]	training's rmse: 4.32518	valid_1's rmse: 5.51716
# [6000]	training's rmse: 4.16358	valid_1's rmse: 5.24874
# [7000]	training's rmse: 4.01058	valid_1's rmse: 5.07
# [8000]	training's rmse: 3.88223	valid_1's rmse: 4.87198
# [9000]	training's rmse: 3.77263	valid_1's rmse: 4.71047
# [10000]	training's rmse: 3.67176	valid_1's rmse: 4.56753
# [11000]	training's rmse: 3.58203	valid_1's rmse: 4.44169
# [12000]	training's rmse: 3.50504	valid_1's rmse: 4.3471
# [13000]	training's rmse: 3.41752	valid_1's rmse: 4.21559
# [14000]	training's rmse: 3.33864	valid_1's rmse: 4.11609
# [15000]	training's rmse: 3.27051	valid_1's rmse: 4.0235
# [16000]	training's rmse: 3.21106	valid_1's rmse: 3.94424
# [17000]	training's rmse: 3.15575	valid_1's rmse: 3.86668
# [18000]	training's rmse: 3.10303	valid_1's rmse: 3.80065
# [19000]	training's rmse: 3.04939	valid_1's rmse: 3.7341
# [20000]	training's rmse: 3.00714	valid_1's rmse: 3.68441
# Did not meet early stopping. Best iteration is:
# [20000]	training's rmse: 3.00714	valid_1's rmse: 3.68441
# Training until validation scores don't improve for 200 rounds
# Early stopping, best iteration is:
# [294]	training's rmse: 7.35675	valid_1's rmse: 5.44162
# Training until validation scores don't improve for 200 rounds
# [1000]	training's rmse: 5.68083	valid_1's rmse: 4.1766
# [2000]	training's rmse: 5.05753	valid_1's rmse: 3.74939
# [3000]	training's rmse: 4.73499	valid_1's rmse: 3.52131
# [4000]	training's rmse: 4.50613	valid_1's rmse: 3.32774
# [5000]	training's rmse: 4.3423	valid_1's rmse: 3.20727
# [6000]	training's rmse: 4.20366	valid_1's rmse: 3.1
# [7000]	training's rmse: 4.10426	valid_1's rmse: 3.02472
# [8000]	training's rmse: 4.00398	valid_1's rmse: 2.9574
# [9000]	training's rmse: 3.9177	valid_1's rmse: 2.90559
# [10000]	training's rmse: 3.84187	valid_1's rmse: 2.86289
# [11000]	training's rmse: 3.76317	valid_1's rmse: 2.81153
# [12000]	training's rmse: 3.69529	valid_1's rmse: 2.77258
# [13000]	training's rmse: 3.62423	valid_1's rmse: 2.73067
# [14000]	training's rmse: 3.55623	valid_1's rmse: 2.68588
# [15000]	training's rmse: 3.49389	valid_1's rmse: 2.64407
# [16000]	training's rmse: 3.43173	valid_1's rmse: 2.60636
# [17000]	training's rmse: 3.37206	valid_1's rmse: 2.57601
# [18000]	training's rmse: 3.32169	valid_1's rmse: 2.5488
# [19000]	training's rmse: 3.26965	valid_1's rmse: 2.5219
# [20000]	training's rmse: 3.22123	valid_1's rmse: 2.4923
# Did not meet early stopping. Best iteration is:
# [20000]	training's rmse: 3.22123	valid_1's rmse: 2.4923
# Training until validation scores don't improve for 200 rounds
# [1000]	training's rmse: 5.68083	valid_1's rmse: 3.58047
# [2000]	training's rmse: 5.05753	valid_1's rmse: 3.32678
# [3000]	training's rmse: 4.73499	valid_1's rmse: 3.14355
# [4000]	training's rmse: 4.50613	valid_1's rmse: 2.97691
# [5000]	training's rmse: 4.3423	valid_1's rmse: 2.88116
# [6000]	training's rmse: 4.20366	valid_1's rmse: 2.75898
# [7000]	training's rmse: 4.10426	valid_1's rmse: 2.68507
# [8000]	training's rmse: 4.00398	valid_1's rmse: 2.61432
# [9000]	training's rmse: 3.9177	valid_1's rmse: 2.55806
# [10000]	training's rmse: 3.84187	valid_1's rmse: 2.50698
# [11000]	training's rmse: 3.76317	valid_1's rmse: 2.45473
# [12000]	training's rmse: 3.69529	valid_1's rmse: 2.41577
# [13000]	training's rmse: 3.62423	valid_1's rmse: 2.36314
# [14000]	training's rmse: 3.55623	valid_1's rmse: 2.31213
# [15000]	training's rmse: 3.49389	valid_1's rmse: 2.27219
# [16000]	training's rmse: 3.43173	valid_1's rmse: 2.23178
# [17000]	training's rmse: 3.37206	valid_1's rmse: 2.20384
# [18000]	training's rmse: 3.32169	valid_1's rmse: 2.1766
# [19000]	training's rmse: 3.26965	valid_1's rmse: 2.14661
# [20000]	training's rmse: 3.22123	valid_1's rmse: 2.11549
# Did not meet early stopping. Best iteration is:
# [20000]	training's rmse: 3.22123	valid_1's rmse: 2.11549
# Training until validation scores don't improve for 200 rounds
# [1000]	training's rmse: 5.68083	valid_1's rmse: 4.11286
# [2000]	training's rmse: 5.05753	valid_1's rmse: 3.74928
# [3000]	training's rmse: 4.73499	valid_1's rmse: 3.48756
# [4000]	training's rmse: 4.50613	valid_1's rmse: 3.25904
# [5000]	training's rmse: 4.3423	valid_1's rmse: 3.14338
# [6000]	training's rmse: 4.20366	valid_1's rmse: 2.99174
# [7000]	training's rmse: 4.10426	valid_1's rmse: 2.91878
# [8000]	training's rmse: 4.00398	valid_1's rmse: 2.83917
# [9000]	training's rmse: 3.9177	valid_1's rmse: 2.78077
# [10000]	training's rmse: 3.84187	valid_1's rmse: 2.74455
# [11000]	training's rmse: 3.76317	valid_1's rmse: 2.68221
# [12000]	training's rmse: 3.69529	valid_1's rmse: 2.64152
# [13000]	training's rmse: 3.62423	valid_1's rmse: 2.59258
# [14000]	training's rmse: 3.55623	valid_1's rmse: 2.54862
# [15000]	training's rmse: 3.49389	valid_1's rmse: 2.51416
# [16000]	training's rmse: 3.43173	valid_1's rmse: 2.47169
# [17000]	training's rmse: 3.37206	valid_1's rmse: 2.43892
# [18000]	training's rmse: 3.32169	valid_1's rmse: 2.41308
# [19000]	training's rmse: 3.26965	valid_1's rmse: 2.39284
# [20000]	training's rmse: 3.22123	valid_1's rmse: 2.36707
# Did not meet early stopping. Best iteration is:
# [20000]	training's rmse: 3.22123	valid_1's rmse: 2.36707
# Training until validation scores don't improve for 200 rounds
# [1000]	training's rmse: 5.68083	valid_1's rmse: 3.47248
# [2000]	training's rmse: 5.05753	valid_1's rmse: 3.15034
# [3000]	training's rmse: 4.73499	valid_1's rmse: 3.02265
# [4000]	training's rmse: 4.50613	valid_1's rmse: 2.90337
# [5000]	training's rmse: 4.3423	valid_1's rmse: 2.84327
# [6000]	training's rmse: 4.20366	valid_1's rmse: 2.78306
# [7000]	training's rmse: 4.10426	valid_1's rmse: 2.71958
# [8000]	training's rmse: 4.00398	valid_1's rmse: 2.66703
# [9000]	training's rmse: 3.9177	valid_1's rmse: 2.6295
# [10000]	training's rmse: 3.84187	valid_1's rmse: 2.5997
# [11000]	training's rmse: 3.76317	valid_1's rmse: 2.5645
# [12000]	training's rmse: 3.69529	valid_1's rmse: 2.52003
# [13000]	training's rmse: 3.62423	valid_1's rmse: 2.48861
# [14000]	training's rmse: 3.55623	valid_1's rmse: 2.46049
# [15000]	training's rmse: 3.49389	valid_1's rmse: 2.43181
# [16000]	training's rmse: 3.43173	valid_1's rmse: 2.39893
# [17000]	training's rmse: 3.37206	valid_1's rmse: 2.36119
# [18000]	training's rmse: 3.32169	valid_1's rmse: 2.33725
# [19000]	training's rmse: 3.26965	valid_1's rmse: 2.30781
# [20000]	training's rmse: 3.22123	valid_1's rmse: 2.28513
# Did not meet early stopping. Best iteration is:
# [20000]	training's rmse: 3.22123	valid_1's rmse: 2.28513
# Training until validation scores don't improve for 200 rounds
# [1000]	training's rmse: 5.68083	valid_1's rmse: 3.67292
# [2000]	training's rmse: 5.05753	valid_1's rmse: 3.305
# [3000]	training's rmse: 4.73499	valid_1's rmse: 3.19112
# [4000]	training's rmse: 4.50613	valid_1's rmse: 3.09169
# [5000]	training's rmse: 4.3423	valid_1's rmse: 3.0434
# [6000]	training's rmse: 4.20366	valid_1's rmse: 2.98708
# [7000]	training's rmse: 4.10426	valid_1's rmse: 2.94879
# [8000]	training's rmse: 4.00398	valid_1's rmse: 2.89769
# [9000]	training's rmse: 3.9177	valid_1's rmse: 2.85144
# [10000]	training's rmse: 3.84187	valid_1's rmse: 2.80795
# [11000]	training's rmse: 3.76317	valid_1's rmse: 2.77045
# [12000]	training's rmse: 3.69529	valid_1's rmse: 2.73187
# [13000]	training's rmse: 3.62423	valid_1's rmse: 2.69737
# [14000]	training's rmse: 3.55623	valid_1's rmse: 2.67011
# [15000]	training's rmse: 3.49389	valid_1's rmse: 2.64405
# [16000]	training's rmse: 3.43173	valid_1's rmse: 2.6198
# [17000]	training's rmse: 3.37206	valid_1's rmse: 2.59043
# [18000]	training's rmse: 3.32169	valid_1's rmse: 2.56324
# [19000]	training's rmse: 3.26965	valid_1's rmse: 2.52881
# [20000]	training's rmse: 3.22123	valid_1's rmse: 2.49968
# Did not meet early stopping. Best iteration is:
# [20000]	training's rmse: 3.22123	valid_1's rmse: 2.49968
# Training until validation scores don't improve for 200 rounds
# [1000]	training's rmse: 5.68083	valid_1's rmse: 5.40005
# [2000]	training's rmse: 5.05753	valid_1's rmse: 5.07454
# [3000]	training's rmse: 4.73499	valid_1's rmse: 4.92998
# [4000]	training's rmse: 4.50613	valid_1's rmse: 4.80977
# [5000]	training's rmse: 4.3423	valid_1's rmse: 4.72238
# [6000]	training's rmse: 4.20366	valid_1's rmse: 4.63553
# [7000]	training's rmse: 4.10426	valid_1's rmse: 4.55702
# [8000]	training's rmse: 4.00398	valid_1's rmse: 4.50239
# [9000]	training's rmse: 3.9177	valid_1's rmse: 4.42933
# [10000]	training's rmse: 3.84187	valid_1's rmse: 4.36486
# [11000]	training's rmse: 3.76317	valid_1's rmse: 4.3103
# [12000]	training's rmse: 3.69529	valid_1's rmse: 4.24238
# [13000]	training's rmse: 3.62423	valid_1's rmse: 4.16011
# [14000]	training's rmse: 3.55623	valid_1's rmse: 4.11222
# [15000]	training's rmse: 3.49389	valid_1's rmse: 4.06279
# [16000]	training's rmse: 3.43173	valid_1's rmse: 4.01328
# [17000]	training's rmse: 3.37206	valid_1's rmse: 3.95203
# [18000]	training's rmse: 3.32169	valid_1's rmse: 3.91123
# [19000]	training's rmse: 3.26965	valid_1's rmse: 3.86432
# [20000]	training's rmse: 3.22123	valid_1's rmse: 3.80888
# Did not meet early stopping. Best iteration is:
# [20000]	training's rmse: 3.22123	valid_1's rmse: 3.80888
# Training until validation scores don't improve for 200 rounds
# [1000]	training's rmse: 5.68083	valid_1's rmse: 3.47562
# [2000]	training's rmse: 5.05753	valid_1's rmse: 3.28228
# [3000]	training's rmse: 4.73499	valid_1's rmse: 3.08319
# [4000]	training's rmse: 4.50613	valid_1's rmse: 2.96415
# [5000]	training's rmse: 4.3423	valid_1's rmse: 2.8822
# [6000]	training's rmse: 4.20366	valid_1's rmse: 2.82012
# [7000]	training's rmse: 4.10426	valid_1's rmse: 2.76842
# [8000]	training's rmse: 4.00398	valid_1's rmse: 2.72436
# [9000]	training's rmse: 3.9177	valid_1's rmse: 2.68436
# [10000]	training's rmse: 3.84187	valid_1's rmse: 2.64978
# [11000]	training's rmse: 3.76317	valid_1's rmse: 2.61526
# [12000]	training's rmse: 3.69529	valid_1's rmse: 2.57737
# [13000]	training's rmse: 3.62423	valid_1's rmse: 2.54019
# [14000]	training's rmse: 3.55623	valid_1's rmse: 2.51075
# [15000]	training's rmse: 3.49389	valid_1's rmse: 2.47931
# [16000]	training's rmse: 3.43173	valid_1's rmse: 2.45357
# [17000]	training's rmse: 3.37206	valid_1's rmse: 2.41512
# [18000]	training's rmse: 3.32169	valid_1's rmse: 2.38877
# [19000]	training's rmse: 3.26965	valid_1's rmse: 2.36529
# [20000]	training's rmse: 3.22123	valid_1's rmse: 2.34351
# Did not meet early stopping. Best iteration is:
# [20000]	training's rmse: 3.22123	valid_1's rmse: 2.34351
# Training until validation scores don't improve for 200 rounds
# [1000]	training's rmse: 5.68083	valid_1's rmse: 3.79894
# [2000]	training's rmse: 5.05753	valid_1's rmse: 3.40762
# [3000]	training's rmse: 4.73499	valid_1's rmse: 3.15598
# [4000]	training's rmse: 4.50613	valid_1's rmse: 2.98264
# [5000]	training's rmse: 4.3423	valid_1's rmse: 2.85418
# [6000]	training's rmse: 4.20366	valid_1's rmse: 2.76396
# [7000]	training's rmse: 4.10426	valid_1's rmse: 2.69412
# [8000]	training's rmse: 4.00398	valid_1's rmse: 2.62977
# [9000]	training's rmse: 3.9177	valid_1's rmse: 2.57904
# [10000]	training's rmse: 3.84187	valid_1's rmse: 2.53464
# [11000]	training's rmse: 3.76317	valid_1's rmse: 2.49338
# [12000]	training's rmse: 3.69529	valid_1's rmse: 2.4538
# [13000]	training's rmse: 3.62423	valid_1's rmse: 2.42136
# [14000]	training's rmse: 3.55623	valid_1's rmse: 2.39226
# [15000]	training's rmse: 3.49389	valid_1's rmse: 2.36561
# [16000]	training's rmse: 3.43173	valid_1's rmse: 2.32886
# [17000]	training's rmse: 3.37206	valid_1's rmse: 2.29985
# [18000]	training's rmse: 3.32169	valid_1's rmse: 2.27641
# [19000]	training's rmse: 3.26965	valid_1's rmse: 2.25039
# [20000]	training's rmse: 3.22123	valid_1's rmse: 2.22762
# Did not meet early stopping. Best iteration is:
# [20000]	training's rmse: 3.22123	valid_1's rmse: 2.22762
# Training until validation scores don't improve for 200 rounds
# [1000]	training's rmse: 5.68083	valid_1's rmse: 3.34516
# [2000]	training's rmse: 5.05753	valid_1's rmse: 3.22453
# [3000]	training's rmse: 4.73499	valid_1's rmse: 3.13252
# [4000]	training's rmse: 4.50613	valid_1's rmse: 3.06008
# [5000]	training's rmse: 4.3423	valid_1's rmse: 3.00211
# [6000]	training's rmse: 4.20366	valid_1's rmse: 2.93195
# [7000]	training's rmse: 4.10426	valid_1's rmse: 2.89056
# [8000]	training's rmse: 4.00398	valid_1's rmse: 2.81705
# [9000]	training's rmse: 3.9177	valid_1's rmse: 2.75058
# [10000]	training's rmse: 3.84187	valid_1's rmse: 2.71699
# [11000]	training's rmse: 3.76317	valid_1's rmse: 2.68833
# [12000]	training's rmse: 3.69529	valid_1's rmse: 2.65289
# [13000]	training's rmse: 3.62423	valid_1's rmse: 2.62009
# [14000]	training's rmse: 3.55623	valid_1's rmse: 2.58808
# [15000]	training's rmse: 3.49389	valid_1's rmse: 2.55019
# [16000]	training's rmse: 3.43173	valid_1's rmse: 2.51767
# [17000]	training's rmse: 3.37206	valid_1's rmse: 2.47662
# [18000]	training's rmse: 3.32169	valid_1's rmse: 2.44918
# [19000]	training's rmse: 3.26965	valid_1's rmse: 2.42138
# [20000]	training's rmse: 3.22123	valid_1's rmse: 2.39532
# Did not meet early stopping. Best iteration is:
# [20000]	training's rmse: 3.22123	valid_1's rmse: 2.39532

# %%
scores
# Out:
# [1.9900157367240736,
#  2.1242259998796262,
#  2.1911500062385088,
#  3.301957230731283,
#  3.684408824981244,
#  5.441621988303744,
#  2.4922983473723,
#  2.1154927858879096,
#  2.3670736414452858,
#  2.285132371705558,
#  2.4996815176548046,
#  3.8088752852236922,
#  2.3435109174274116,
#  2.2276171140520393,
#  2.3953156213835456]

# %%
# 予測
test_x["y"] = model.predict(test_x)

# %%
test_x.to_pickle('../input/pickle/test_pc_game.zip')

# %%
# path = "../submission/"

# submission = pd.read_csv(path + "sample_submission.csv", header=None)

# submission.iloc[:,[1]] = pred
# submission.head()

# %%
# submission.to_csv(path + "submission.csv", index=False, header=None)

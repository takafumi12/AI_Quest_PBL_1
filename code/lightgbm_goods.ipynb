# %%
import numpy as np
import pandas as pd
from pandas import DataFrame, Series
import matplotlib.pyplot as plt
import seaborn as sns
import lightgbm as lgb

from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import LabelEncoder

# 最大表示列数の指定（ここでは50列を指定）
pd.set_option("display.max_columns", 1000)
pd.set_option("display.max_rows", 1000)

import warnings
warnings.filterwarnings("ignore")

# %%
path = "../input/pickle/"

train = pd.read_pickle(path + "train.zip")

train = train[train["item_category_big"]==2].copy().reset_index(drop=True)

train_x = train.drop(["y"], axis=1)
train_y = train["y"]
test_x = pd.read_pickle(path + "test.zip")

train.drop("item_category_big", axis=1, inplace=True)

test_x = test_x[test_x["item_category_big"]==2].copy()

test_x.drop("item_category_big", axis=1, inplace=True)

# %%
train_x.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60764 entries, 0 to 60763
# Data columns (total 11 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   year                   60764 non-null  int64
#  1   month                  60764 non-null  int64
#  2   shopID                 60764 non-null  int64
#  3   itemID                 60764 non-null  int64
#  4   item_categoryID        60764 non-null  int64
#  5   item_category_big      60764 non-null  int64
#  6   release_time           60764 non-null  float64
#  7   sale_last_month        60764 non-null  float64
#  8   item_price_last_month  60764 non-null  float64
#  9   item_price_difference  60764 non-null  int64
#  10  item_price             60764 non-null  float64
# dtypes: float64(4), int64(7)
# memory usage: 5.1 MB

# %%
test_x.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1170 entries, 1206 to 2879
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   itemID                 1170 non-null   int64
#  1   shopID                 1170 non-null   int64
#  2   item_categoryID        1170 non-null   int64
#  3   month                  1170 non-null   int64
#  4   year                   1170 non-null   int64
#  5   release_time           1170 non-null   int64
#  6   sale_last_month        1170 non-null   float64
#  7   item_price_last_month  1170 non-null   float64
#  8   item_price_difference  1170 non-null   float64
#  9   item_price             1170 non-null   float64
# dtypes: float64(4), int64(6)
# memory usage: 100.5 KB

# %%
train_x.index
# Out:
# RangeIndex(start=0, stop=60764, step=1)

# %%
years = [2018] * 6 + [2019] * 9
months = list(range(7, 13)) + list(range(1, 10))

# %%
month_list = list(range(1, 7))
year_list = [2017] + [2018]

scores = []

# custom function to run light gbm model
def run_lgb(train_X, train_y, val_X, val_y, x_test):
    params = {"objective" : "regression", 
              "metric" : "rmse", 
              "n_estimators":20000, 
              "early_stopping_rounds":200,
              "num_leaves" : 31, 
              "learning_rate" : 0.01, 
              "bagging_fraction" : 0.7,
              "bagging_seed" : 0, 
              "num_threads" : 4,
              "colsample_bytree" : 0.7,
              'max_depth': 5
             }
    
    lgtrain = lgb.Dataset(tr_x, tr_y)
    lgval = lgb.Dataset(va_x, va_y)
    model = lgb.train(params, lgtrain, 
                      valid_sets=[lgtrain, lgval], 
                      verbose_eval=1000)
    
    pred_test_y = model.predict(x_test, num_iteration=model.best_iteration)
    return pred_test_y, model

for year, month in zip(years, months):
    if year == 2019 and len(year_list) == 2:
        year_list.append(year)
    
    month_list.append(month)
    
    if month == 12:
        year += 1
        month = 1
    
    tr_x = train_x[(train_x["year"].isin(year_list))&(train_x["month"].isin(month_list))]
    va_x = train_x[(train_x["year"] == year)&(train_x["month"] == month)]
    tr_y, va_y = train_y.iloc[tr_x.index], train_y.iloc[va_x.index]
    
    # Training the model
    pred_test, model = run_lgb(tr_x, tr_y, va_x, va_y, test_x)
    
    # バリデーションデータでのスコアの確認
    va_pred = model.predict(va_x)
    score = np.sqrt(mean_squared_error(va_y, va_pred))
    
    scores.append(score)
# Out:
# Training until validation scores don't improve for 200 rounds
# [1000]	training's rmse: 2.12765	valid_1's rmse: 1.99925
# [2000]	training's rmse: 1.98032	valid_1's rmse: 1.86629
# [3000]	training's rmse: 1.8877	valid_1's rmse: 1.7619
# [4000]	training's rmse: 1.83029	valid_1's rmse: 1.70514
# [5000]	training's rmse: 1.78484	valid_1's rmse: 1.6634
# [6000]	training's rmse: 1.7458	valid_1's rmse: 1.61237
# [7000]	training's rmse: 1.71089	valid_1's rmse: 1.5668
# [8000]	training's rmse: 1.6799	valid_1's rmse: 1.53329
# [9000]	training's rmse: 1.65274	valid_1's rmse: 1.50269
# [10000]	training's rmse: 1.62623	valid_1's rmse: 1.46899
# [11000]	training's rmse: 1.60121	valid_1's rmse: 1.44086
# [12000]	training's rmse: 1.57863	valid_1's rmse: 1.41403
# [13000]	training's rmse: 1.55888	valid_1's rmse: 1.39146
# [14000]	training's rmse: 1.53802	valid_1's rmse: 1.37089
# [15000]	training's rmse: 1.51816	valid_1's rmse: 1.34842
# [16000]	training's rmse: 1.50097	valid_1's rmse: 1.32764
# [17000]	training's rmse: 1.48399	valid_1's rmse: 1.30884
# [18000]	training's rmse: 1.46496	valid_1's rmse: 1.28723
# [19000]	training's rmse: 1.44764	valid_1's rmse: 1.26961
# [20000]	training's rmse: 1.43037	valid_1's rmse: 1.24839
# Did not meet early stopping. Best iteration is:
# [20000]	training's rmse: 1.43037	valid_1's rmse: 1.24839
# Training until validation scores don't improve for 200 rounds
# [1000]	training's rmse: 2.13798	valid_1's rmse: 2.10536
# [2000]	training's rmse: 1.99675	valid_1's rmse: 1.98054
# [3000]	training's rmse: 1.93061	valid_1's rmse: 1.90741
# [4000]	training's rmse: 1.88465	valid_1's rmse: 1.85555
# [5000]	training's rmse: 1.84263	valid_1's rmse: 1.80889
# [6000]	training's rmse: 1.80537	valid_1's rmse: 1.7715
# [7000]	training's rmse: 1.76956	valid_1's rmse: 1.73414
# [8000]	training's rmse: 1.72826	valid_1's rmse: 1.68413
# [9000]	training's rmse: 1.69556	valid_1's rmse: 1.63852
# [10000]	training's rmse: 1.67132	valid_1's rmse: 1.60838
# [11000]	training's rmse: 1.6489	valid_1's rmse: 1.5864
# [12000]	training's rmse: 1.62853	valid_1's rmse: 1.56247
# [13000]	training's rmse: 1.60541	valid_1's rmse: 1.53522
# [14000]	training's rmse: 1.58527	valid_1's rmse: 1.50886
# [15000]	training's rmse: 1.56509	valid_1's rmse: 1.48646
# [16000]	training's rmse: 1.54557	valid_1's rmse: 1.46476
# [17000]	training's rmse: 1.53022	valid_1's rmse: 1.45054
# [18000]	training's rmse: 1.50948	valid_1's rmse: 1.42234
# [19000]	training's rmse: 1.49537	valid_1's rmse: 1.40962
# [20000]	training's rmse: 1.47816	valid_1's rmse: 1.39209
# Did not meet early stopping. Best iteration is:
# [20000]	training's rmse: 1.47816	valid_1's rmse: 1.39209
# Training until validation scores don't improve for 200 rounds
# [1000]	training's rmse: 2.16467	valid_1's rmse: 2.04408
# [2000]	training's rmse: 2.04118	valid_1's rmse: 1.93022
# [3000]	training's rmse: 1.97044	valid_1's rmse: 1.8464
# [4000]	training's rmse: 1.92142	valid_1's rmse: 1.79674
# [5000]	training's rmse: 1.87069	valid_1's rmse: 1.7494
# [6000]	training's rmse: 1.82604	valid_1's rmse: 1.71244
# [7000]	training's rmse: 1.78401	valid_1's rmse: 1.66802
# [8000]	training's rmse: 1.74419	valid_1's rmse: 1.62089
# [9000]	training's rmse: 1.7092	valid_1's rmse: 1.58796
# [10000]	training's rmse: 1.68047	valid_1's rmse: 1.56279
# [11000]	training's rmse: 1.65457	valid_1's rmse: 1.53533
# [12000]	training's rmse: 1.63104	valid_1's rmse: 1.51392
# [13000]	training's rmse: 1.60769	valid_1's rmse: 1.48945
# [14000]	training's rmse: 1.59096	valid_1's rmse: 1.47398
# [15000]	training's rmse: 1.57393	valid_1's rmse: 1.44916
# [16000]	training's rmse: 1.55791	valid_1's rmse: 1.42753
# [17000]	training's rmse: 1.54317	valid_1's rmse: 1.40615
# [18000]	training's rmse: 1.52739	valid_1's rmse: 1.3882
# [19000]	training's rmse: 1.50756	valid_1's rmse: 1.36392
# [20000]	training's rmse: 1.49228	valid_1's rmse: 1.34257
# Did not meet early stopping. Best iteration is:
# [20000]	training's rmse: 1.49228	valid_1's rmse: 1.34257
# Training until validation scores don't improve for 200 rounds
# [1000]	training's rmse: 2.38761	valid_1's rmse: 3.7203
# [2000]	training's rmse: 2.23764	valid_1's rmse: 3.48301
# [3000]	training's rmse: 2.14744	valid_1's rmse: 3.35578
# [4000]	training's rmse: 2.07189	valid_1's rmse: 3.22348
# [5000]	training's rmse: 2.01698	valid_1's rmse: 3.12829
# [6000]	training's rmse: 1.9734	valid_1's rmse: 3.0566
# [7000]	training's rmse: 1.9376	valid_1's rmse: 2.9865
# [8000]	training's rmse: 1.91436	valid_1's rmse: 2.94469
# [9000]	training's rmse: 1.88249	valid_1's rmse: 2.87668
# [10000]	training's rmse: 1.85241	valid_1's rmse: 2.82449
# [11000]	training's rmse: 1.82804	valid_1's rmse: 2.77339
# [12000]	training's rmse: 1.80698	valid_1's rmse: 2.72902
# [13000]	training's rmse: 1.78691	valid_1's rmse: 2.69252
# [14000]	training's rmse: 1.76743	valid_1's rmse: 2.65889
# [15000]	training's rmse: 1.7446	valid_1's rmse: 2.59947
# [16000]	training's rmse: 1.72441	valid_1's rmse: 2.54772
# [17000]	training's rmse: 1.70755	valid_1's rmse: 2.51429
# [18000]	training's rmse: 1.68734	valid_1's rmse: 2.46772
# [19000]	training's rmse: 1.66674	valid_1's rmse: 2.41242
# [20000]	training's rmse: 1.65042	valid_1's rmse: 2.38191
# Did not meet early stopping. Best iteration is:
# [20000]	training's rmse: 1.65042	valid_1's rmse: 2.38191
# Training until validation scores don't improve for 200 rounds
# [1000]	training's rmse: 2.39688	valid_1's rmse: 2.27928
# [2000]	training's rmse: 2.25124	valid_1's rmse: 2.12911
# [3000]	training's rmse: 2.17376	valid_1's rmse: 2.04871
# [4000]	training's rmse: 2.10902	valid_1's rmse: 1.98794
# [5000]	training's rmse: 2.06244	valid_1's rmse: 1.94559
# [6000]	training's rmse: 2.01684	valid_1's rmse: 1.89496
# [7000]	training's rmse: 1.98221	valid_1's rmse: 1.85759
# [8000]	training's rmse: 1.9448	valid_1's rmse: 1.81116
# [9000]	training's rmse: 1.90995	valid_1's rmse: 1.77649
# [10000]	training's rmse: 1.88338	valid_1's rmse: 1.74077
# [11000]	training's rmse: 1.85784	valid_1's rmse: 1.71687
# [12000]	training's rmse: 1.83375	valid_1's rmse: 1.69004
# [13000]	training's rmse: 1.80751	valid_1's rmse: 1.66214
# [14000]	training's rmse: 1.78481	valid_1's rmse: 1.64026
# [15000]	training's rmse: 1.76148	valid_1's rmse: 1.61768
# [16000]	training's rmse: 1.74329	valid_1's rmse: 1.5988
# [17000]	training's rmse: 1.72555	valid_1's rmse: 1.58355
# [18000]	training's rmse: 1.70668	valid_1's rmse: 1.56667
# [19000]	training's rmse: 1.68676	valid_1's rmse: 1.54006
# [20000]	training's rmse: 1.66719	valid_1's rmse: 1.51875
# Did not meet early stopping. Best iteration is:
# [20000]	training's rmse: 1.66719	valid_1's rmse: 1.51875
# Training until validation scores don't improve for 200 rounds
# Early stopping, best iteration is:
# [416]	training's rmse: 2.87448	valid_1's rmse: 2.91204
# Training until validation scores don't improve for 200 rounds
# [1000]	training's rmse: 2.79767	valid_1's rmse: 2.5844
# [2000]	training's rmse: 2.67087	valid_1's rmse: 2.4211
# [3000]	training's rmse: 2.57028	valid_1's rmse: 2.32016
# [4000]	training's rmse: 2.49571	valid_1's rmse: 2.24298
# [5000]	training's rmse: 2.43444	valid_1's rmse: 2.17173
# [6000]	training's rmse: 2.38801	valid_1's rmse: 2.12336
# [7000]	training's rmse: 2.34834	valid_1's rmse: 2.08135
# [8000]	training's rmse: 2.31835	valid_1's rmse: 2.05363
# [9000]	training's rmse: 2.28579	valid_1's rmse: 2.02062
# [10000]	training's rmse: 2.2546	valid_1's rmse: 1.99272
# [11000]	training's rmse: 2.2256	valid_1's rmse: 1.96129
# [12000]	training's rmse: 2.19696	valid_1's rmse: 1.93507
# [13000]	training's rmse: 2.17275	valid_1's rmse: 1.91436
# [14000]	training's rmse: 2.15188	valid_1's rmse: 1.90002
# [15000]	training's rmse: 2.13105	valid_1's rmse: 1.88301
# [16000]	training's rmse: 2.11555	valid_1's rmse: 1.87198
# [17000]	training's rmse: 2.09483	valid_1's rmse: 1.85326
# [18000]	training's rmse: 2.0776	valid_1's rmse: 1.83994
# [19000]	training's rmse: 2.05798	valid_1's rmse: 1.82422
# [20000]	training's rmse: 2.0412	valid_1's rmse: 1.80817
# Did not meet early stopping. Best iteration is:
# [20000]	training's rmse: 2.0412	valid_1's rmse: 1.80817
# Training until validation scores don't improve for 200 rounds
# [1000]	training's rmse: 2.79767	valid_1's rmse: 2.21533
# [2000]	training's rmse: 2.67087	valid_1's rmse: 2.12749
# [3000]	training's rmse: 2.57028	valid_1's rmse: 2.06465
# [4000]	training's rmse: 2.49571	valid_1's rmse: 2.01154
# [5000]	training's rmse: 2.43444	valid_1's rmse: 1.96791
# [6000]	training's rmse: 2.38801	valid_1's rmse: 1.92955
# [7000]	training's rmse: 2.34834	valid_1's rmse: 1.89321
# [8000]	training's rmse: 2.31835	valid_1's rmse: 1.86618
# [9000]	training's rmse: 2.28579	valid_1's rmse: 1.83716
# [10000]	training's rmse: 2.2546	valid_1's rmse: 1.809
# [11000]	training's rmse: 2.2256	valid_1's rmse: 1.7819
# [12000]	training's rmse: 2.19696	valid_1's rmse: 1.75601
# [13000]	training's rmse: 2.17275	valid_1's rmse: 1.73529
# [14000]	training's rmse: 2.15188	valid_1's rmse: 1.71883
# [15000]	training's rmse: 2.13105	valid_1's rmse: 1.69612
# [16000]	training's rmse: 2.11555	valid_1's rmse: 1.68086
# [17000]	training's rmse: 2.09483	valid_1's rmse: 1.66615
# [18000]	training's rmse: 2.0776	valid_1's rmse: 1.65295
# [19000]	training's rmse: 2.05798	valid_1's rmse: 1.63815
# [20000]	training's rmse: 2.0412	valid_1's rmse: 1.62435
# Did not meet early stopping. Best iteration is:
# [20000]	training's rmse: 2.0412	valid_1's rmse: 1.62435
# Training until validation scores don't improve for 200 rounds
# [1000]	training's rmse: 2.79767	valid_1's rmse: 2.27398
# [2000]	training's rmse: 2.67087	valid_1's rmse: 2.17321
# [3000]	training's rmse: 2.57028	valid_1's rmse: 2.08726
# [4000]	training's rmse: 2.49571	valid_1's rmse: 2.01306
# [5000]	training's rmse: 2.43444	valid_1's rmse: 1.96398
# [6000]	training's rmse: 2.38801	valid_1's rmse: 1.92105
# [7000]	training's rmse: 2.34834	valid_1's rmse: 1.88497
# [8000]	training's rmse: 2.31835	valid_1's rmse: 1.85883
# [9000]	training's rmse: 2.28579	valid_1's rmse: 1.82658
# [10000]	training's rmse: 2.2546	valid_1's rmse: 1.80089
# [11000]	training's rmse: 2.2256	valid_1's rmse: 1.77347
# [12000]	training's rmse: 2.19696	valid_1's rmse: 1.74626
# [13000]	training's rmse: 2.17275	valid_1's rmse: 1.72719
# [14000]	training's rmse: 2.15188	valid_1's rmse: 1.7107
# [15000]	training's rmse: 2.13105	valid_1's rmse: 1.69034
# [16000]	training's rmse: 2.11555	valid_1's rmse: 1.67966
# [17000]	training's rmse: 2.09483	valid_1's rmse: 1.65888
# [18000]	training's rmse: 2.0776	valid_1's rmse: 1.64161
# [19000]	training's rmse: 2.05798	valid_1's rmse: 1.62452
# [20000]	training's rmse: 2.0412	valid_1's rmse: 1.61345
# Did not meet early stopping. Best iteration is:
# [20000]	training's rmse: 2.0412	valid_1's rmse: 1.61345
# Training until validation scores don't improve for 200 rounds
# [1000]	training's rmse: 2.79767	valid_1's rmse: 2.07697
# [2000]	training's rmse: 2.67087	valid_1's rmse: 2.02126
# [3000]	training's rmse: 2.57028	valid_1's rmse: 1.97517
# [4000]	training's rmse: 2.49571	valid_1's rmse: 1.9309
# [5000]	training's rmse: 2.43444	valid_1's rmse: 1.9001
# [6000]	training's rmse: 2.38801	valid_1's rmse: 1.87412
# [7000]	training's rmse: 2.34834	valid_1's rmse: 1.85178
# [8000]	training's rmse: 2.31835	valid_1's rmse: 1.83615
# [9000]	training's rmse: 2.28579	valid_1's rmse: 1.8175
# [10000]	training's rmse: 2.2546	valid_1's rmse: 1.80189
# [11000]	training's rmse: 2.2256	valid_1's rmse: 1.786
# [12000]	training's rmse: 2.19696	valid_1's rmse: 1.76931
# [13000]	training's rmse: 2.17275	valid_1's rmse: 1.75652
# [14000]	training's rmse: 2.15188	valid_1's rmse: 1.7462
# [15000]	training's rmse: 2.13105	valid_1's rmse: 1.73119
# [16000]	training's rmse: 2.11555	valid_1's rmse: 1.72147
# [17000]	training's rmse: 2.09483	valid_1's rmse: 1.70591
# [18000]	training's rmse: 2.0776	valid_1's rmse: 1.69638
# [19000]	training's rmse: 2.05798	valid_1's rmse: 1.68369
# [20000]	training's rmse: 2.0412	valid_1's rmse: 1.6731
# Did not meet early stopping. Best iteration is:
# [20000]	training's rmse: 2.0412	valid_1's rmse: 1.6731
# Training until validation scores don't improve for 200 rounds
# [1000]	training's rmse: 2.79767	valid_1's rmse: 1.93924
# [2000]	training's rmse: 2.67087	valid_1's rmse: 1.86505
# [3000]	training's rmse: 2.57028	valid_1's rmse: 1.81285
# [4000]	training's rmse: 2.49571	valid_1's rmse: 1.77906
# [5000]	training's rmse: 2.43444	valid_1's rmse: 1.73789
# [6000]	training's rmse: 2.38801	valid_1's rmse: 1.70854
# [7000]	training's rmse: 2.34834	valid_1's rmse: 1.67879
# [8000]	training's rmse: 2.31835	valid_1's rmse: 1.66166
# [9000]	training's rmse: 2.28579	valid_1's rmse: 1.63631
# [10000]	training's rmse: 2.2546	valid_1's rmse: 1.61842
# [11000]	training's rmse: 2.2256	valid_1's rmse: 1.59498
# [12000]	training's rmse: 2.19696	valid_1's rmse: 1.57598
# [13000]	training's rmse: 2.17275	valid_1's rmse: 1.56017
# [14000]	training's rmse: 2.15188	valid_1's rmse: 1.54817
# [15000]	training's rmse: 2.13105	valid_1's rmse: 1.53632
# [16000]	training's rmse: 2.11555	valid_1's rmse: 1.52474
# [17000]	training's rmse: 2.09483	valid_1's rmse: 1.51495
# [18000]	training's rmse: 2.0776	valid_1's rmse: 1.50301
# [19000]	training's rmse: 2.05798	valid_1's rmse: 1.49503
# [20000]	training's rmse: 2.0412	valid_1's rmse: 1.48853
# Did not meet early stopping. Best iteration is:
# [20000]	training's rmse: 2.0412	valid_1's rmse: 1.48853
# Training until validation scores don't improve for 200 rounds
# [1000]	training's rmse: 2.79767	valid_1's rmse: 1.72244
# [2000]	training's rmse: 2.67087	valid_1's rmse: 1.66563
# [3000]	training's rmse: 2.57028	valid_1's rmse: 1.61642
# [4000]	training's rmse: 2.49571	valid_1's rmse: 1.57555
# [5000]	training's rmse: 2.43444	valid_1's rmse: 1.54374
# [6000]	training's rmse: 2.38801	valid_1's rmse: 1.51313
# [7000]	training's rmse: 2.34834	valid_1's rmse: 1.49229
# [8000]	training's rmse: 2.31835	valid_1's rmse: 1.47767
# [9000]	training's rmse: 2.28579	valid_1's rmse: 1.45998
# [10000]	training's rmse: 2.2546	valid_1's rmse: 1.44525
# [11000]	training's rmse: 2.2256	valid_1's rmse: 1.43025
# [12000]	training's rmse: 2.19696	valid_1's rmse: 1.41744
# [13000]	training's rmse: 2.17275	valid_1's rmse: 1.40716
# [14000]	training's rmse: 2.15188	valid_1's rmse: 1.39857
# [15000]	training's rmse: 2.13105	valid_1's rmse: 1.39153
# [16000]	training's rmse: 2.11555	valid_1's rmse: 1.38483
# [17000]	training's rmse: 2.09483	valid_1's rmse: 1.37802
# [18000]	training's rmse: 2.0776	valid_1's rmse: 1.36938
# [19000]	training's rmse: 2.05798	valid_1's rmse: 1.36165
# [20000]	training's rmse: 2.0412	valid_1's rmse: 1.3552
# Did not meet early stopping. Best iteration is:
# [20000]	training's rmse: 2.0412	valid_1's rmse: 1.3552
# Training until validation scores don't improve for 200 rounds
# [1000]	training's rmse: 2.79767	valid_1's rmse: 1.80231
# [2000]	training's rmse: 2.67087	valid_1's rmse: 1.74502
# [3000]	training's rmse: 2.57028	valid_1's rmse: 1.69602
# [4000]	training's rmse: 2.49571	valid_1's rmse: 1.6564
# [5000]	training's rmse: 2.43444	valid_1's rmse: 1.62238
# [6000]	training's rmse: 2.38801	valid_1's rmse: 1.59206
# [7000]	training's rmse: 2.34834	valid_1's rmse: 1.56744
# [8000]	training's rmse: 2.31835	valid_1's rmse: 1.55037
# [9000]	training's rmse: 2.28579	valid_1's rmse: 1.53175
# [10000]	training's rmse: 2.2546	valid_1's rmse: 1.51865
# [11000]	training's rmse: 2.2256	valid_1's rmse: 1.50188
# [12000]	training's rmse: 2.19696	valid_1's rmse: 1.48985
# [13000]	training's rmse: 2.17275	valid_1's rmse: 1.4781
# [14000]	training's rmse: 2.15188	valid_1's rmse: 1.46949
# [15000]	training's rmse: 2.13105	valid_1's rmse: 1.4614
# [16000]	training's rmse: 2.11555	valid_1's rmse: 1.45422
# [17000]	training's rmse: 2.09483	valid_1's rmse: 1.44413
# [18000]	training's rmse: 2.0776	valid_1's rmse: 1.43606
# [19000]	training's rmse: 2.05798	valid_1's rmse: 1.4279
# [20000]	training's rmse: 2.0412	valid_1's rmse: 1.42133
# Did not meet early stopping. Best iteration is:
# [20000]	training's rmse: 2.0412	valid_1's rmse: 1.42133
# Training until validation scores don't improve for 200 rounds
# [1000]	training's rmse: 2.79767	valid_1's rmse: 2.52722
# [2000]	training's rmse: 2.67087	valid_1's rmse: 2.42677
# [3000]	training's rmse: 2.57028	valid_1's rmse: 2.30396
# [4000]	training's rmse: 2.49571	valid_1's rmse: 2.2048
# [5000]	training's rmse: 2.43444	valid_1's rmse: 2.13079
# [6000]	training's rmse: 2.38801	valid_1's rmse: 2.0676
# [7000]	training's rmse: 2.34834	valid_1's rmse: 2.02699
# [8000]	training's rmse: 2.31835	valid_1's rmse: 2.00322
# [9000]	training's rmse: 2.28579	valid_1's rmse: 1.97442
# [10000]	training's rmse: 2.2546	valid_1's rmse: 1.94109
# [11000]	training's rmse: 2.2256	valid_1's rmse: 1.90927
# [12000]	training's rmse: 2.19696	valid_1's rmse: 1.87903
# [13000]	training's rmse: 2.17275	valid_1's rmse: 1.85231
# [14000]	training's rmse: 2.15188	valid_1's rmse: 1.83609
# [15000]	training's rmse: 2.13105	valid_1's rmse: 1.81913
# [16000]	training's rmse: 2.11555	valid_1's rmse: 1.80884
# [17000]	training's rmse: 2.09483	valid_1's rmse: 1.78993
# [18000]	training's rmse: 2.0776	valid_1's rmse: 1.77683
# [19000]	training's rmse: 2.05798	valid_1's rmse: 1.76367
# [20000]	training's rmse: 2.0412	valid_1's rmse: 1.75012
# Did not meet early stopping. Best iteration is:
# [20000]	training's rmse: 2.0412	valid_1's rmse: 1.75012
# Training until validation scores don't improve for 200 rounds
# [1000]	training's rmse: 2.79767	valid_1's rmse: 2.34298
# [2000]	training's rmse: 2.67087	valid_1's rmse: 2.27301
# [3000]	training's rmse: 2.57028	valid_1's rmse: 2.20297
# [4000]	training's rmse: 2.49571	valid_1's rmse: 2.13692
# [5000]	training's rmse: 2.43444	valid_1's rmse: 2.09402
# [6000]	training's rmse: 2.38801	valid_1's rmse: 2.06021
# [7000]	training's rmse: 2.34834	valid_1's rmse: 2.02993
# [8000]	training's rmse: 2.31835	valid_1's rmse: 2.00949
# [9000]	training's rmse: 2.28579	valid_1's rmse: 1.9869
# [10000]	training's rmse: 2.2546	valid_1's rmse: 1.97097
# [11000]	training's rmse: 2.2256	valid_1's rmse: 1.95122
# [12000]	training's rmse: 2.19696	valid_1's rmse: 1.934
# [13000]	training's rmse: 2.17275	valid_1's rmse: 1.91735
# [14000]	training's rmse: 2.15188	valid_1's rmse: 1.90436
# [15000]	training's rmse: 2.13105	valid_1's rmse: 1.89076
# [16000]	training's rmse: 2.11555	valid_1's rmse: 1.87791
# [17000]	training's rmse: 2.09483	valid_1's rmse: 1.86535
# [18000]	training's rmse: 2.0776	valid_1's rmse: 1.85668
# [19000]	training's rmse: 2.05798	valid_1's rmse: 1.84484
# [20000]	training's rmse: 2.0412	valid_1's rmse: 1.83956
# Did not meet early stopping. Best iteration is:
# [20000]	training's rmse: 2.0412	valid_1's rmse: 1.83956

# %%
scores
# Out:
# [1.2483931988258186,
#  1.392086182507728,
#  1.3425670288177705,
#  2.3819119423916324,
#  1.5187477013706838,
#  2.912041355940584,
#  1.8081668500008106,
#  1.6243504720837676,
#  1.6134501429587633,
#  1.6731014509705766,
#  1.4885300233052425,
#  1.3551959718612103,
#  1.4213307926474623,
#  1.7501217022055127,
#  1.839562202145546]

# %%
# 予測
test_x["y"] = model.predict(test_x)

# %%
test_x.to_pickle('../input/pickle/test_goods.zip')

# %%
# path = "../submission/"

# submission = pd.read_csv(path + "sample_submission.csv", header=None)

# submission.iloc[:,[1]] = pred
# submission.head()

# %%
# submission.to_csv(path + "submission.csv", index=False, header=None)

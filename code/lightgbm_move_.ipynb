# %%
import numpy as np
import pandas as pd
from pandas import DataFrame, Series
import matplotlib.pyplot as plt
import seaborn as sns
import lightgbm as lgb

from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import LabelEncoder

# 最大表示列数の指定（ここでは50列を指定）
pd.set_option("display.max_columns", 1000)
pd.set_option("display.max_rows", 1000)

import warnings
warnings.filterwarnings("ignore")

# %%
path = "../input/pickle/"

train = pd.read_pickle(path + "train.zip")

train = train[train["item_category_big"]==5].copy().reset_index(drop=True)
train.drop("item_category_big", axis=1, inplace=True)

train_x = train.drop(["y"], axis=1)
train_y = train["y"]
test_x = pd.read_pickle(path + "test.zip")

test_x = test_x[test_x["item_category_big"]==5].copy()

test_x.drop("item_category_big", axis=1, inplace=True)

# %%
train_x.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 198555 entries, 0 to 198554
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   year                   198555 non-null  int64
#  1   month                  198555 non-null  int64
#  2   shopID                 198555 non-null  int64
#  3   itemID                 198555 non-null  int64
#  4   item_categoryID        198555 non-null  int64
#  5   release_time           198555 non-null  float64
#  6   sale_last_month        198555 non-null  float64
#  7   item_price_last_month  198555 non-null  float64
#  8   item_price_difference  198555 non-null  int64
#  9   item_price             198555 non-null  float64
# dtypes: float64(4), int64(6)
# memory usage: 15.1 MB

# %%
test_x.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 486 entries, 0 to 2033
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   itemID                 486 non-null    int64
#  1   shopID                 486 non-null    int64
#  2   item_categoryID        486 non-null    int64
#  3   month                  486 non-null    int64
#  4   year                   486 non-null    int64
#  5   release_time           486 non-null    int64
#  6   sale_last_month        486 non-null    float64
#  7   item_price_last_month  486 non-null    float64
#  8   item_price_difference  486 non-null    float64
#  9   item_price             486 non-null    float64
# dtypes: float64(4), int64(6)
# memory usage: 41.8 KB

# %%
train_x.index
# Out:
# RangeIndex(start=0, stop=198555, step=1)

# %%
years = [2018] * 6 + [2019] * 9
months = list(range(7, 13)) + list(range(1, 10))

# %%
month_list = list(range(1, 7))
year_list = [2017] + [2018]

scores = []

# custom function to run light gbm model
def run_lgb(train_X, train_y, val_X, val_y, x_test):
    params = {"objective" : "regression", 
              "metric" : "rmse", 
              "n_estimators":20000, 
              "early_stopping_rounds":200,
              "num_leaves" : 31, 
              "learning_rate" : 0.01, 
              "bagging_fraction" : 0.7,
              "bagging_seed" : 0, 
              "num_threads" : 4,
              "colsample_bytree" : 0.7,
              'max_depth': 5
             }
    
    lgtrain = lgb.Dataset(tr_x, tr_y)
    lgval = lgb.Dataset(va_x, va_y)
    model = lgb.train(params, lgtrain, 
                      valid_sets=[lgtrain, lgval], 
                      verbose_eval=1000)
    
    pred_test_y = model.predict(x_test, num_iteration=model.best_iteration)
    return pred_test_y, model

for year, month in zip(years, months):
    if year == 2019 and len(year_list) == 2:
        year_list.append(year)
    
    month_list.append(month)
    
    if month == 12:
        year += 1
        month = 1
    
    tr_x = train_x[(train_x["year"].isin(year_list))&(train_x["month"].isin(month_list))]
    va_x = train_x[(train_x["year"] == year)&(train_x["month"] == month)]
    tr_y, va_y = train_y.iloc[tr_x.index], train_y.iloc[va_x.index]
    
    # Training the model
    pred_test, model = run_lgb(tr_x, tr_y, va_x, va_y, test_x)
    
    # バリデーションデータでのスコアの確認
    va_pred = model.predict(va_x)
    score = np.sqrt(mean_squared_error(va_y, va_pred))
    
    scores.append(score)
# Out:
# Training until validation scores don't improve for 200 rounds
# [1000]	training's rmse: 2.86481	valid_1's rmse: 1.90296
# [2000]	training's rmse: 2.65052	valid_1's rmse: 1.80192
# [3000]	training's rmse: 2.50558	valid_1's rmse: 1.7507
# [4000]	training's rmse: 2.41838	valid_1's rmse: 1.71336
# [5000]	training's rmse: 2.34222	valid_1's rmse: 1.67541
# [6000]	training's rmse: 2.29936	valid_1's rmse: 1.64728
# [7000]	training's rmse: 2.24604	valid_1's rmse: 1.61155
# [8000]	training's rmse: 2.18798	valid_1's rmse: 1.58187
# [9000]	training's rmse: 2.14764	valid_1's rmse: 1.55517
# [10000]	training's rmse: 2.10834	valid_1's rmse: 1.53784
# [11000]	training's rmse: 2.05891	valid_1's rmse: 1.50626
# [12000]	training's rmse: 2.03203	valid_1's rmse: 1.48671
# [13000]	training's rmse: 2.0064	valid_1's rmse: 1.47081
# [14000]	training's rmse: 1.9852	valid_1's rmse: 1.45535
# [15000]	training's rmse: 1.96132	valid_1's rmse: 1.44454
# [16000]	training's rmse: 1.93413	valid_1's rmse: 1.43628
# [17000]	training's rmse: 1.90931	valid_1's rmse: 1.4266
# [18000]	training's rmse: 1.89144	valid_1's rmse: 1.41949
# [19000]	training's rmse: 1.87176	valid_1's rmse: 1.40959
# [20000]	training's rmse: 1.85498	valid_1's rmse: 1.40114
# Did not meet early stopping. Best iteration is:
# [20000]	training's rmse: 1.85498	valid_1's rmse: 1.40114
# Training until validation scores don't improve for 200 rounds
# [1000]	training's rmse: 2.82847	valid_1's rmse: 2.12978
# [2000]	training's rmse: 2.61381	valid_1's rmse: 2.01833
# [3000]	training's rmse: 2.47241	valid_1's rmse: 1.93967
# [4000]	training's rmse: 2.38143	valid_1's rmse: 1.89022
# [5000]	training's rmse: 2.31424	valid_1's rmse: 1.85217
# [6000]	training's rmse: 2.25868	valid_1's rmse: 1.80561
# [7000]	training's rmse: 2.21276	valid_1's rmse: 1.77801
# [8000]	training's rmse: 2.16853	valid_1's rmse: 1.7405
# [9000]	training's rmse: 2.1209	valid_1's rmse: 1.71575
# [10000]	training's rmse: 2.08807	valid_1's rmse: 1.6961
# [11000]	training's rmse: 2.05853	valid_1's rmse: 1.68041
# [12000]	training's rmse: 2.03515	valid_1's rmse: 1.65956
# [13000]	training's rmse: 2.00546	valid_1's rmse: 1.64076
# [14000]	training's rmse: 1.97961	valid_1's rmse: 1.62829
# [15000]	training's rmse: 1.95761	valid_1's rmse: 1.61778
# [16000]	training's rmse: 1.93761	valid_1's rmse: 1.60577
# [17000]	training's rmse: 1.91805	valid_1's rmse: 1.5945
# [18000]	training's rmse: 1.90262	valid_1's rmse: 1.58345
# [19000]	training's rmse: 1.8836	valid_1's rmse: 1.57457
# [20000]	training's rmse: 1.86628	valid_1's rmse: 1.56443
# Did not meet early stopping. Best iteration is:
# [20000]	training's rmse: 1.86628	valid_1's rmse: 1.56443
# Training until validation scores don't improve for 200 rounds
# [1000]	training's rmse: 2.82938	valid_1's rmse: 2.75828
# [2000]	training's rmse: 2.62379	valid_1's rmse: 2.59509
# [3000]	training's rmse: 2.50339	valid_1's rmse: 2.51262
# [4000]	training's rmse: 2.41774	valid_1's rmse: 2.41799
# [5000]	training's rmse: 2.34513	valid_1's rmse: 2.36867
# [6000]	training's rmse: 2.2873	valid_1's rmse: 2.33309
# [7000]	training's rmse: 2.24596	valid_1's rmse: 2.30007
# [8000]	training's rmse: 2.2115	valid_1's rmse: 2.2721
# [9000]	training's rmse: 2.17011	valid_1's rmse: 2.23838
# [10000]	training's rmse: 2.13179	valid_1's rmse: 2.21678
# [11000]	training's rmse: 2.1042	valid_1's rmse: 2.19667
# [12000]	training's rmse: 2.07732	valid_1's rmse: 2.18219
# [13000]	training's rmse: 2.05091	valid_1's rmse: 2.16708
# [14000]	training's rmse: 2.02734	valid_1's rmse: 2.15103
# [15000]	training's rmse: 2.00469	valid_1's rmse: 2.14061
# [16000]	training's rmse: 1.97873	valid_1's rmse: 2.1137
# [17000]	training's rmse: 1.95831	valid_1's rmse: 2.09897
# [18000]	training's rmse: 1.93888	valid_1's rmse: 2.08858
# [19000]	training's rmse: 1.92939	valid_1's rmse: 2.07943
# [20000]	training's rmse: 1.91009	valid_1's rmse: 2.06252
# Did not meet early stopping. Best iteration is:
# [20000]	training's rmse: 1.91009	valid_1's rmse: 2.06252
# Training until validation scores don't improve for 200 rounds
# [1000]	training's rmse: 2.8699	valid_1's rmse: 3.14176
# [2000]	training's rmse: 2.69852	valid_1's rmse: 3.02652
# [3000]	training's rmse: 2.55835	valid_1's rmse: 2.92016
# [4000]	training's rmse: 2.46941	valid_1's rmse: 2.85215
# [5000]	training's rmse: 2.40677	valid_1's rmse: 2.79974
# [6000]	training's rmse: 2.35768	valid_1's rmse: 2.75847
# [7000]	training's rmse: 2.30921	valid_1's rmse: 2.69175
# [8000]	training's rmse: 2.26897	valid_1's rmse: 2.65456
# [9000]	training's rmse: 2.23565	valid_1's rmse: 2.63078
# [10000]	training's rmse: 2.20849	valid_1's rmse: 2.61333
# [11000]	training's rmse: 2.18491	valid_1's rmse: 2.58598
# [12000]	training's rmse: 2.16119	valid_1's rmse: 2.56237
# [13000]	training's rmse: 2.14495	valid_1's rmse: 2.54583
# [14000]	training's rmse: 2.12334	valid_1's rmse: 2.52204
# [15000]	training's rmse: 2.09963	valid_1's rmse: 2.49446
# [16000]	training's rmse: 2.07687	valid_1's rmse: 2.46819
# [17000]	training's rmse: 2.06225	valid_1's rmse: 2.45615
# [18000]	training's rmse: 2.04556	valid_1's rmse: 2.43495
# [19000]	training's rmse: 2.02627	valid_1's rmse: 2.41842
# [20000]	training's rmse: 2.00805	valid_1's rmse: 2.39235
# Did not meet early stopping. Best iteration is:
# [20000]	training's rmse: 2.00805	valid_1's rmse: 2.39235
# Training until validation scores don't improve for 200 rounds
# [1000]	training's rmse: 2.87379	valid_1's rmse: 2.62837
# [2000]	training's rmse: 2.70455	valid_1's rmse: 2.54217
# [3000]	training's rmse: 2.57759	valid_1's rmse: 2.47239
# [4000]	training's rmse: 2.48582	valid_1's rmse: 2.4029
# [5000]	training's rmse: 2.42465	valid_1's rmse: 2.36375
# [6000]	training's rmse: 2.38347	valid_1's rmse: 2.32503
# [7000]	training's rmse: 2.34995	valid_1's rmse: 2.29474
# [8000]	training's rmse: 2.30727	valid_1's rmse: 2.26828
# [9000]	training's rmse: 2.27883	valid_1's rmse: 2.24633
# [10000]	training's rmse: 2.25561	valid_1's rmse: 2.22038
# [11000]	training's rmse: 2.23078	valid_1's rmse: 2.2007
# [12000]	training's rmse: 2.20803	valid_1's rmse: 2.18422
# [13000]	training's rmse: 2.18841	valid_1's rmse: 2.17251
# [14000]	training's rmse: 2.16384	valid_1's rmse: 2.15459
# [15000]	training's rmse: 2.14904	valid_1's rmse: 2.14393
# [16000]	training's rmse: 2.13968	valid_1's rmse: 2.13723
# [17000]	training's rmse: 2.12376	valid_1's rmse: 2.1245
# [18000]	training's rmse: 2.10076	valid_1's rmse: 2.10512
# [19000]	training's rmse: 2.09083	valid_1's rmse: 2.09584
# [20000]	training's rmse: 2.07317	valid_1's rmse: 2.08309
# Did not meet early stopping. Best iteration is:
# [20000]	training's rmse: 2.07317	valid_1's rmse: 2.08309
# Training until validation scores don't improve for 200 rounds
# Early stopping, best iteration is:
# [571]	training's rmse: 3.09594	valid_1's rmse: 2.82623
# Training until validation scores don't improve for 200 rounds
# [1000]	training's rmse: 2.79566	valid_1's rmse: 2.63586
# [2000]	training's rmse: 2.6432	valid_1's rmse: 2.40546
# [3000]	training's rmse: 2.558	valid_1's rmse: 2.30488
# [4000]	training's rmse: 2.4956	valid_1's rmse: 2.24029
# [5000]	training's rmse: 2.45248	valid_1's rmse: 2.21033
# [6000]	training's rmse: 2.41316	valid_1's rmse: 2.17509
# [7000]	training's rmse: 2.37971	valid_1's rmse: 2.15135
# [8000]	training's rmse: 2.34718	valid_1's rmse: 2.13057
# [9000]	training's rmse: 2.31561	valid_1's rmse: 2.10909
# [10000]	training's rmse: 2.29124	valid_1's rmse: 2.08826
# [11000]	training's rmse: 2.26491	valid_1's rmse: 2.06228
# [12000]	training's rmse: 2.24291	valid_1's rmse: 2.04163
# [13000]	training's rmse: 2.22649	valid_1's rmse: 2.02775
# [14000]	training's rmse: 2.21082	valid_1's rmse: 2.01138
# [15000]	training's rmse: 2.19429	valid_1's rmse: 1.99424
# [16000]	training's rmse: 2.17298	valid_1's rmse: 1.97699
# [17000]	training's rmse: 2.15419	valid_1's rmse: 1.96721
# [18000]	training's rmse: 2.14122	valid_1's rmse: 1.95746
# [19000]	training's rmse: 2.12405	valid_1's rmse: 1.93926
# [20000]	training's rmse: 2.10796	valid_1's rmse: 1.9315
# Did not meet early stopping. Best iteration is:
# [20000]	training's rmse: 2.10796	valid_1's rmse: 1.9315
# Training until validation scores don't improve for 200 rounds
# [1000]	training's rmse: 2.79566	valid_1's rmse: 2.4318
# [2000]	training's rmse: 2.6432	valid_1's rmse: 2.37478
# [3000]	training's rmse: 2.558	valid_1's rmse: 2.33644
# [4000]	training's rmse: 2.4956	valid_1's rmse: 2.29233
# [5000]	training's rmse: 2.45248	valid_1's rmse: 2.26142
# [6000]	training's rmse: 2.41316	valid_1's rmse: 2.243
# [7000]	training's rmse: 2.37971	valid_1's rmse: 2.22503
# [8000]	training's rmse: 2.34718	valid_1's rmse: 2.20736
# [9000]	training's rmse: 2.31561	valid_1's rmse: 2.18991
# [10000]	training's rmse: 2.29124	valid_1's rmse: 2.16908
# [11000]	training's rmse: 2.26491	valid_1's rmse: 2.1518
# [12000]	training's rmse: 2.24291	valid_1's rmse: 2.13044
# [13000]	training's rmse: 2.22649	valid_1's rmse: 2.11809
# [14000]	training's rmse: 2.21082	valid_1's rmse: 2.10908
# [15000]	training's rmse: 2.19429	valid_1's rmse: 2.09937
# [16000]	training's rmse: 2.17298	valid_1's rmse: 2.07769
# [17000]	training's rmse: 2.15419	valid_1's rmse: 2.06212
# [18000]	training's rmse: 2.14122	valid_1's rmse: 2.05087
# [19000]	training's rmse: 2.12405	valid_1's rmse: 2.03859
# [20000]	training's rmse: 2.10796	valid_1's rmse: 2.03187
# Did not meet early stopping. Best iteration is:
# [20000]	training's rmse: 2.10796	valid_1's rmse: 2.03187
# Training until validation scores don't improve for 200 rounds
# [1000]	training's rmse: 2.79566	valid_1's rmse: 3.55887
# [2000]	training's rmse: 2.6432	valid_1's rmse: 3.43782
# [3000]	training's rmse: 2.558	valid_1's rmse: 3.37957
# [4000]	training's rmse: 2.4956	valid_1's rmse: 3.32028
# [5000]	training's rmse: 2.45248	valid_1's rmse: 3.25816
# [6000]	training's rmse: 2.41316	valid_1's rmse: 3.17569
# [7000]	training's rmse: 2.37971	valid_1's rmse: 3.13689
# [8000]	training's rmse: 2.34718	valid_1's rmse: 3.09396
# [9000]	training's rmse: 2.31561	valid_1's rmse: 3.02184
# [10000]	training's rmse: 2.29124	valid_1's rmse: 2.97979
# [11000]	training's rmse: 2.26491	valid_1's rmse: 2.95119
# [12000]	training's rmse: 2.24291	valid_1's rmse: 2.92431
# [13000]	training's rmse: 2.22649	valid_1's rmse: 2.90792
# [14000]	training's rmse: 2.21082	valid_1's rmse: 2.88926
# [15000]	training's rmse: 2.19429	valid_1's rmse: 2.87366
# [16000]	training's rmse: 2.17298	valid_1's rmse: 2.81724
# [17000]	training's rmse: 2.15419	valid_1's rmse: 2.78503
# [18000]	training's rmse: 2.14122	valid_1's rmse: 2.77024
# [19000]	training's rmse: 2.12405	valid_1's rmse: 2.74495
# [20000]	training's rmse: 2.10796	valid_1's rmse: 2.7117
# Did not meet early stopping. Best iteration is:
# [20000]	training's rmse: 2.10796	valid_1's rmse: 2.7117
# Training until validation scores don't improve for 200 rounds
# [1000]	training's rmse: 2.79566	valid_1's rmse: 2.78687
# [2000]	training's rmse: 2.6432	valid_1's rmse: 2.68506
# [3000]	training's rmse: 2.558	valid_1's rmse: 2.61943
# [4000]	training's rmse: 2.4956	valid_1's rmse: 2.56046
# [5000]	training's rmse: 2.45248	valid_1's rmse: 2.50453
# [6000]	training's rmse: 2.41316	valid_1's rmse: 2.48195
# [7000]	training's rmse: 2.37971	valid_1's rmse: 2.45401
# [8000]	training's rmse: 2.34718	valid_1's rmse: 2.42507
# [9000]	training's rmse: 2.31561	valid_1's rmse: 2.39704
# [10000]	training's rmse: 2.29124	valid_1's rmse: 2.35183
# [11000]	training's rmse: 2.26491	valid_1's rmse: 2.32303
# [12000]	training's rmse: 2.24291	valid_1's rmse: 2.30531
# [13000]	training's rmse: 2.22649	valid_1's rmse: 2.29274
# [14000]	training's rmse: 2.21082	valid_1's rmse: 2.28338
# [15000]	training's rmse: 2.19429	valid_1's rmse: 2.27296
# [16000]	training's rmse: 2.17298	valid_1's rmse: 2.24712
# [17000]	training's rmse: 2.15419	valid_1's rmse: 2.22657
# [18000]	training's rmse: 2.14122	valid_1's rmse: 2.21326
# [19000]	training's rmse: 2.12405	valid_1's rmse: 2.18473
# [20000]	training's rmse: 2.10796	valid_1's rmse: 2.16415
# Did not meet early stopping. Best iteration is:
# [20000]	training's rmse: 2.10796	valid_1's rmse: 2.16415
# Training until validation scores don't improve for 200 rounds
# [1000]	training's rmse: 2.79566	valid_1's rmse: 1.78802
# [2000]	training's rmse: 2.6432	valid_1's rmse: 1.73019
# [3000]	training's rmse: 2.558	valid_1's rmse: 1.69683
# [4000]	training's rmse: 2.4956	valid_1's rmse: 1.66407
# [5000]	training's rmse: 2.45248	valid_1's rmse: 1.63557
# [6000]	training's rmse: 2.41316	valid_1's rmse: 1.6218
# [7000]	training's rmse: 2.37971	valid_1's rmse: 1.61186
# [8000]	training's rmse: 2.34718	valid_1's rmse: 1.59629
# [9000]	training's rmse: 2.31561	valid_1's rmse: 1.58358
# [10000]	training's rmse: 2.29124	valid_1's rmse: 1.57099
# [11000]	training's rmse: 2.26491	valid_1's rmse: 1.55926
# [12000]	training's rmse: 2.24291	valid_1's rmse: 1.54648
# [13000]	training's rmse: 2.22649	valid_1's rmse: 1.53666
# [14000]	training's rmse: 2.21082	valid_1's rmse: 1.52969
# [15000]	training's rmse: 2.19429	valid_1's rmse: 1.5226
# [16000]	training's rmse: 2.17298	valid_1's rmse: 1.51003
# [17000]	training's rmse: 2.15419	valid_1's rmse: 1.50188
# [18000]	training's rmse: 2.14122	valid_1's rmse: 1.49573
# [19000]	training's rmse: 2.12405	valid_1's rmse: 1.48667
# [20000]	training's rmse: 2.10796	valid_1's rmse: 1.47141
# Did not meet early stopping. Best iteration is:
# [20000]	training's rmse: 2.10796	valid_1's rmse: 1.47141
# Training until validation scores don't improve for 200 rounds
# [1000]	training's rmse: 2.79566	valid_1's rmse: 1.66597
# [2000]	training's rmse: 2.6432	valid_1's rmse: 1.63766
# [3000]	training's rmse: 2.558	valid_1's rmse: 1.62141
# [4000]	training's rmse: 2.4956	valid_1's rmse: 1.60764
# [5000]	training's rmse: 2.45248	valid_1's rmse: 1.59455
# [6000]	training's rmse: 2.41316	valid_1's rmse: 1.58679
# [7000]	training's rmse: 2.37971	valid_1's rmse: 1.58138
# [8000]	training's rmse: 2.34718	valid_1's rmse: 1.57368
# [9000]	training's rmse: 2.31561	valid_1's rmse: 1.56628
# [10000]	training's rmse: 2.29124	valid_1's rmse: 1.56241
# Early stopping, best iteration is:
# [10114]	training's rmse: 2.28706	valid_1's rmse: 1.56212
# Training until validation scores don't improve for 200 rounds
# [1000]	training's rmse: 2.79566	valid_1's rmse: 1.60776
# [2000]	training's rmse: 2.6432	valid_1's rmse: 1.56887
# [3000]	training's rmse: 2.558	valid_1's rmse: 1.54115
# [4000]	training's rmse: 2.4956	valid_1's rmse: 1.51642
# [5000]	training's rmse: 2.45248	valid_1's rmse: 1.4899
# [6000]	training's rmse: 2.41316	valid_1's rmse: 1.476
# [7000]	training's rmse: 2.37971	valid_1's rmse: 1.46401
# [8000]	training's rmse: 2.34718	valid_1's rmse: 1.45018
# [9000]	training's rmse: 2.31561	valid_1's rmse: 1.43747
# [10000]	training's rmse: 2.29124	valid_1's rmse: 1.43103
# [11000]	training's rmse: 2.26491	valid_1's rmse: 1.41963
# [12000]	training's rmse: 2.24291	valid_1's rmse: 1.40995
# [13000]	training's rmse: 2.22649	valid_1's rmse: 1.40168
# [14000]	training's rmse: 2.21082	valid_1's rmse: 1.39661
# [15000]	training's rmse: 2.19429	valid_1's rmse: 1.39019
# [16000]	training's rmse: 2.17298	valid_1's rmse: 1.38178
# [17000]	training's rmse: 2.15419	valid_1's rmse: 1.37438
# [18000]	training's rmse: 2.14122	valid_1's rmse: 1.36855
# [19000]	training's rmse: 2.12405	valid_1's rmse: 1.36155
# [20000]	training's rmse: 2.10796	valid_1's rmse: 1.35568
# Did not meet early stopping. Best iteration is:
# [20000]	training's rmse: 2.10796	valid_1's rmse: 1.35568
# Training until validation scores don't improve for 200 rounds
# [1000]	training's rmse: 2.79566	valid_1's rmse: 2.03654
# [2000]	training's rmse: 2.6432	valid_1's rmse: 1.9758
# [3000]	training's rmse: 2.558	valid_1's rmse: 1.93446
# [4000]	training's rmse: 2.4956	valid_1's rmse: 1.89959
# [5000]	training's rmse: 2.45248	valid_1's rmse: 1.87171
# [6000]	training's rmse: 2.41316	valid_1's rmse: 1.85302
# [7000]	training's rmse: 2.37971	valid_1's rmse: 1.83972
# [8000]	training's rmse: 2.34718	valid_1's rmse: 1.82178
# [9000]	training's rmse: 2.31561	valid_1's rmse: 1.80475
# [10000]	training's rmse: 2.29124	valid_1's rmse: 1.7943
# [11000]	training's rmse: 2.26491	valid_1's rmse: 1.78828
# [12000]	training's rmse: 2.24291	valid_1's rmse: 1.78011
# [13000]	training's rmse: 2.22649	valid_1's rmse: 1.77342
# [14000]	training's rmse: 2.21082	valid_1's rmse: 1.76617
# [15000]	training's rmse: 2.19429	valid_1's rmse: 1.76059
# [16000]	training's rmse: 2.17298	valid_1's rmse: 1.74988
# [17000]	training's rmse: 2.15419	valid_1's rmse: 1.7409
# [18000]	training's rmse: 2.14122	valid_1's rmse: 1.7345
# [19000]	training's rmse: 2.12405	valid_1's rmse: 1.72655
# [20000]	training's rmse: 2.10796	valid_1's rmse: 1.7194
# Did not meet early stopping. Best iteration is:
# [20000]	training's rmse: 2.10796	valid_1's rmse: 1.7194
# Training until validation scores don't improve for 200 rounds
# [1000]	training's rmse: 2.79566	valid_1's rmse: 1.82774
# [2000]	training's rmse: 2.6432	valid_1's rmse: 1.78946
# [3000]	training's rmse: 2.558	valid_1's rmse: 1.77158
# [4000]	training's rmse: 2.4956	valid_1's rmse: 1.74913
# [5000]	training's rmse: 2.45248	valid_1's rmse: 1.72795
# [6000]	training's rmse: 2.41316	valid_1's rmse: 1.71374
# [7000]	training's rmse: 2.37971	valid_1's rmse: 1.70196
# [8000]	training's rmse: 2.34718	valid_1's rmse: 1.69051
# [9000]	training's rmse: 2.31561	valid_1's rmse: 1.67632
# [10000]	training's rmse: 2.29124	valid_1's rmse: 1.67167
# [11000]	training's rmse: 2.26491	valid_1's rmse: 1.66474
# [12000]	training's rmse: 2.24291	valid_1's rmse: 1.6586
# [13000]	training's rmse: 2.22649	valid_1's rmse: 1.6533
# [14000]	training's rmse: 2.21082	valid_1's rmse: 1.64891
# [15000]	training's rmse: 2.19429	valid_1's rmse: 1.64124
# [16000]	training's rmse: 2.17298	valid_1's rmse: 1.634
# [17000]	training's rmse: 2.15419	valid_1's rmse: 1.6277
# [18000]	training's rmse: 2.14122	valid_1's rmse: 1.62113
# [19000]	training's rmse: 2.12405	valid_1's rmse: 1.61565
# [20000]	training's rmse: 2.10796	valid_1's rmse: 1.60981
# Did not meet early stopping. Best iteration is:
# [20000]	training's rmse: 2.10796	valid_1's rmse: 1.60981

# %%
scores
# Out:
# [1.401137315904138,
#  1.564433759329293,
#  2.062524196437948,
#  2.392346590063118,
#  2.083094576797465,
#  2.826230213194018,
#  1.9315048685632035,
#  2.0318657126340187,
#  2.7116981409275893,
#  2.1641459991275713,
#  1.4714126683049564,
#  1.5621185327766287,
#  1.3556794881094052,
#  1.7194028579160034,
#  1.609813722733601]

# %%
# 予測
test_x["y"] = model.predict(test_x)

# %%
test_x.to_pickle('../input/pickle/test_move.zip')

# %%
# path = "../submission/"

# submission = pd.read_csv(path + "sample_submission.csv", header=None)

# submission.iloc[:,[1]] = pred
# submission.head()

# %%
# submission.to_csv(path + "submission.csv", index=False, header=None)

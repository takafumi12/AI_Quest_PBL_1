# %%
import numpy as np
import pandas as pd
from pandas import DataFrame, Series
import matplotlib.pyplot as plt
import seaborn as sns
import lightgbm as lgb

from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import LabelEncoder

# 最大表示列数の指定（ここでは50列を指定）
pd.set_option("display.max_columns", 1000)
pd.set_option("display.max_rows", 1000)

import warnings
warnings.filterwarnings("ignore")

# %%
path = "../input/pickle/"

train = pd.read_pickle(path + "train.zip")

train = train[train["item_category_big"]==4].copy().reset_index(drop=True)

train_x = train.drop(["y"], axis=1)
train_y = train["y"]
test_x = pd.read_pickle(path + "test.zip")

train.drop("item_category_big", axis=1, inplace=True)

test_x = test_x[test_x["item_category_big"]==4].copy()

test.drop("item_category_big", axis=1, inplace=True)

# %%
train_x.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5887 entries, 0 to 5886
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   year               5887 non-null   int64
#  1   month              5887 non-null   int64
#  2   shopID             5887 non-null   int64
#  3   itemID             5887 non-null   int64
#  4   item_categoryID    5887 non-null   int64
#  5   item_category_big  5887 non-null   int64
#  6   item_price         5887 non-null   int64
#  7   release_time       5887 non-null   float64
# dtypes: float64(1), int64(7)
# memory usage: 368.1 KB

# %%
test_x.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 90 entries, 0 to 89
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   itemID             90 non-null     int64
#  1   shopID             90 non-null     int64
#  2   item_categoryID    90 non-null     int64
#  3   item_category_big  90 non-null     int64
#  4   month              90 non-null     int64
#  5   year               90 non-null     int64
#  6   item_price         90 non-null     float64
#  7   release_time       90 non-null     int64
# dtypes: float64(1), int64(7)
# memory usage: 5.8 KB

# %%
train_x.index
# Out:
# RangeIndex(start=0, stop=5887, step=1)

# %%
years = [2018] * 6 + [2019] * 9
months = list(range(7, 13)) + list(range(1, 10))

# %%
month_list = list(range(1, 7))
year_list = [2017] + [2018]

scores = []

# custom function to run light gbm model
def run_lgb(train_X, train_y, val_X, val_y, x_test):
    params = {"objective" : "regression", 
              "metric" : "rmse", 
              "n_estimators":20000, 
              "early_stopping_rounds":200,
              "num_leaves" : 31, 
              "learning_rate" : 0.01, 
              "bagging_fraction" : 0.7,
              "bagging_seed" : 0, 
              "num_threads" : 4,
              "colsample_bytree" : 0.7,
              'max_depth': 5
             }
    
    lgtrain = lgb.Dataset(tr_x, tr_y)
    lgval = lgb.Dataset(va_x, va_y)
    model = lgb.train(params, lgtrain, 
                      valid_sets=[lgtrain, lgval], 
                      verbose_eval=1000)
    
    pred_test_y = model.predict(x_test, num_iteration=model.best_iteration)
    return pred_test_y, model

for year, month in zip(years, months):
    if year == 2019 and len(year_list) == 1:
        year_list = year_list.append(year)
    
    month_list.append(month)
    
    if month == 12:
        year += 1
        month = 1
    
    tr_x = train_x[(train_x["year"].isin(year_list))&(train_x["month"].isin(month_list))]
    va_x = train_x[(train_x["year"] == year)&(train_x["month"] == month)]
    tr_y, va_y = train_y.iloc[tr_x.index], train_y.iloc[va_x.index]
    
    # Training the model
    pred_test, model = run_lgb(tr_x, tr_y, va_x, va_y, test_x)
    
    # バリデーションデータでのスコアの確認
    va_pred = model.predict(va_x)
    score = np.sqrt(mean_squared_error(va_y, va_pred))
    
    scores.append(score)
# Out:
# Training until validation scores don't improve for 200 rounds
# [1000]	training's rmse: 1.42343	valid_1's rmse: 1.63051
# [2000]	training's rmse: 1.29261	valid_1's rmse: 1.42618
# [3000]	training's rmse: 1.20871	valid_1's rmse: 1.30625
# [4000]	training's rmse: 1.13628	valid_1's rmse: 1.21192
# [5000]	training's rmse: 1.08185	valid_1's rmse: 1.14764
# [6000]	training's rmse: 1.04089	valid_1's rmse: 1.09301
# [7000]	training's rmse: 1.00105	valid_1's rmse: 1.0437
# [8000]	training's rmse: 0.965444	valid_1's rmse: 1.00241
# [9000]	training's rmse: 0.936372	valid_1's rmse: 0.957988
# [10000]	training's rmse: 0.912181	valid_1's rmse: 0.924949
# [11000]	training's rmse: 0.886471	valid_1's rmse: 0.895264
# [12000]	training's rmse: 0.861446	valid_1's rmse: 0.865939
# [13000]	training's rmse: 0.832887	valid_1's rmse: 0.841915
# [14000]	training's rmse: 0.814362	valid_1's rmse: 0.822988
# [15000]	training's rmse: 0.798911	valid_1's rmse: 0.798733
# [16000]	training's rmse: 0.781295	valid_1's rmse: 0.774173
# [17000]	training's rmse: 0.767638	valid_1's rmse: 0.756463
# [18000]	training's rmse: 0.756933	valid_1's rmse: 0.732922
# [19000]	training's rmse: 0.742789	valid_1's rmse: 0.713325
# [20000]	training's rmse: 0.72937	valid_1's rmse: 0.694945
# Did not meet early stopping. Best iteration is:
# [20000]	training's rmse: 0.72937	valid_1's rmse: 0.694945
# Training until validation scores don't improve for 200 rounds
# [1000]	training's rmse: 1.37365	valid_1's rmse: 1.01554
# [2000]	training's rmse: 1.22312	valid_1's rmse: 0.890481
# [3000]	training's rmse: 1.13543	valid_1's rmse: 0.826381
# [4000]	training's rmse: 1.07917	valid_1's rmse: 0.770386
# [5000]	training's rmse: 1.03617	valid_1's rmse: 0.726667
# [6000]	training's rmse: 0.993131	valid_1's rmse: 0.696431
# [7000]	training's rmse: 0.962395	valid_1's rmse: 0.670456
# [8000]	training's rmse: 0.932561	valid_1's rmse: 0.651199
# [9000]	training's rmse: 0.905072	valid_1's rmse: 0.630552
# [10000]	training's rmse: 0.88553	valid_1's rmse: 0.617346
# [11000]	training's rmse: 0.864276	valid_1's rmse: 0.595988
# [12000]	training's rmse: 0.843603	valid_1's rmse: 0.580191
# [13000]	training's rmse: 0.821493	valid_1's rmse: 0.566602
# [14000]	training's rmse: 0.802739	valid_1's rmse: 0.550865
# [15000]	training's rmse: 0.782982	valid_1's rmse: 0.53744
# [16000]	training's rmse: 0.76438	valid_1's rmse: 0.527264
# [17000]	training's rmse: 0.7487	valid_1's rmse: 0.517989
# [18000]	training's rmse: 0.731356	valid_1's rmse: 0.510172
# [19000]	training's rmse: 0.718058	valid_1's rmse: 0.500589
# [20000]	training's rmse: 0.706423	valid_1's rmse: 0.491036
# Did not meet early stopping. Best iteration is:
# [20000]	training's rmse: 0.706423	valid_1's rmse: 0.491036
# Training until validation scores don't improve for 200 rounds
# [1000]	training's rmse: 1.37215	valid_1's rmse: 1.28888
# [2000]	training's rmse: 1.2617	valid_1's rmse: 1.12604
# [3000]	training's rmse: 1.18993	valid_1's rmse: 1.02203
# [4000]	training's rmse: 1.13448	valid_1's rmse: 0.944641
# [5000]	training's rmse: 1.09375	valid_1's rmse: 0.885865
# [6000]	training's rmse: 1.05877	valid_1's rmse: 0.844942
# [7000]	training's rmse: 1.01659	valid_1's rmse: 0.802451
# [8000]	training's rmse: 0.984265	valid_1's rmse: 0.774256
# [9000]	training's rmse: 0.957055	valid_1's rmse: 0.754854
# [10000]	training's rmse: 0.931669	valid_1's rmse: 0.732573
# [11000]	training's rmse: 0.912245	valid_1's rmse: 0.713081
# [12000]	training's rmse: 0.894362	valid_1's rmse: 0.69482
# [13000]	training's rmse: 0.87657	valid_1's rmse: 0.67773
# [14000]	training's rmse: 0.858283	valid_1's rmse: 0.665856
# [15000]	training's rmse: 0.840327	valid_1's rmse: 0.648187
# [16000]	training's rmse: 0.821504	valid_1's rmse: 0.631311
# [17000]	training's rmse: 0.803591	valid_1's rmse: 0.614665
# [18000]	training's rmse: 0.789383	valid_1's rmse: 0.604589
# [19000]	training's rmse: 0.773725	valid_1's rmse: 0.591475
# [20000]	training's rmse: 0.759122	valid_1's rmse: 0.575829
# Did not meet early stopping. Best iteration is:
# [20000]	training's rmse: 0.759122	valid_1's rmse: 0.575829
# Training until validation scores don't improve for 200 rounds
# [1000]	training's rmse: 1.5941	valid_1's rmse: 2.69568
# [2000]	training's rmse: 1.46345	valid_1's rmse: 2.37428
# [3000]	training's rmse: 1.38204	valid_1's rmse: 2.15963
# [4000]	training's rmse: 1.32715	valid_1's rmse: 2.0118
# [5000]	training's rmse: 1.27598	valid_1's rmse: 1.87071
# [6000]	training's rmse: 1.24082	valid_1's rmse: 1.77584
# [7000]	training's rmse: 1.20517	valid_1's rmse: 1.67785
# [8000]	training's rmse: 1.16754	valid_1's rmse: 1.59823
# [9000]	training's rmse: 1.13501	valid_1's rmse: 1.52602
# [10000]	training's rmse: 1.1068	valid_1's rmse: 1.47573
# [11000]	training's rmse: 1.07916	valid_1's rmse: 1.41499
# [12000]	training's rmse: 1.05889	valid_1's rmse: 1.35489
# [13000]	training's rmse: 1.03566	valid_1's rmse: 1.30432
# [14000]	training's rmse: 1.00893	valid_1's rmse: 1.26635
# [15000]	training's rmse: 0.983738	valid_1's rmse: 1.23295
# [16000]	training's rmse: 0.961968	valid_1's rmse: 1.19225
# [17000]	training's rmse: 0.943806	valid_1's rmse: 1.15152
# [18000]	training's rmse: 0.930387	valid_1's rmse: 1.10762
# [19000]	training's rmse: 0.915764	valid_1's rmse: 1.07439
# [20000]	training's rmse: 0.900475	valid_1's rmse: 1.04387
# Did not meet early stopping. Best iteration is:
# [20000]	training's rmse: 0.900475	valid_1's rmse: 1.04387
# Training until validation scores don't improve for 200 rounds
# [1000]	training's rmse: 1.5414	valid_1's rmse: 1.46206
# [2000]	training's rmse: 1.41045	valid_1's rmse: 1.29239
# [3000]	training's rmse: 1.32239	valid_1's rmse: 1.16105
# [4000]	training's rmse: 1.27323	valid_1's rmse: 1.09001
# [5000]	training's rmse: 1.23201	valid_1's rmse: 1.04803
# [6000]	training's rmse: 1.19047	valid_1's rmse: 0.980996
# [7000]	training's rmse: 1.1494	valid_1's rmse: 0.933576
# [8000]	training's rmse: 1.12297	valid_1's rmse: 0.89819
# [9000]	training's rmse: 1.09035	valid_1's rmse: 0.863976
# [10000]	training's rmse: 1.06307	valid_1's rmse: 0.837919
# [11000]	training's rmse: 1.04483	valid_1's rmse: 0.812735
# [12000]	training's rmse: 1.02548	valid_1's rmse: 0.79215
# [13000]	training's rmse: 1.00278	valid_1's rmse: 0.767364
# [14000]	training's rmse: 0.986222	valid_1's rmse: 0.744685
# [15000]	training's rmse: 0.971421	valid_1's rmse: 0.723747
# [16000]	training's rmse: 0.959057	valid_1's rmse: 0.701337
# [17000]	training's rmse: 0.943145	valid_1's rmse: 0.690658
# [18000]	training's rmse: 0.930845	valid_1's rmse: 0.672646
# [19000]	training's rmse: 0.916436	valid_1's rmse: 0.65459
# [20000]	training's rmse: 0.901124	valid_1's rmse: 0.640728
# Did not meet early stopping. Best iteration is:
# [20000]	training's rmse: 0.901124	valid_1's rmse: 0.640728
# Training until validation scores don't improve for 200 rounds
# [1000]	training's rmse: 1.65743	valid_1's rmse: 2.89445
# [2000]	training's rmse: 1.51944	valid_1's rmse: 2.81712
# Early stopping, best iteration is:
# [1813]	training's rmse: 1.54051	valid_1's rmse: 2.80649
# Training until validation scores don't improve for 200 rounds
# [1000]	training's rmse: 1.65743	valid_1's rmse: 2.89445
# [2000]	training's rmse: 1.51944	valid_1's rmse: 2.81712
# Early stopping, best iteration is:
# [1813]	training's rmse: 1.54051	valid_1's rmse: 2.80649
# Training until validation scores don't improve for 200 rounds
# Early stopping, best iteration is:
# [36]	training's rmse: 3.12872	valid_1's rmse: 2.16355
# Training until validation scores don't improve for 200 rounds
# Early stopping, best iteration is:
# [63]	training's rmse: 2.84176	valid_1's rmse: 1.77759
# Training until validation scores don't improve for 200 rounds
# Early stopping, best iteration is:
# [79]	training's rmse: 2.71126	valid_1's rmse: 1.69105
# Training until validation scores don't improve for 200 rounds
# Early stopping, best iteration is:
# [58]	training's rmse: 2.89211	valid_1's rmse: 1.74528
# Training until validation scores don't improve for 200 rounds
# Early stopping, best iteration is:
# [50]	training's rmse: 2.96928	valid_1's rmse: 1.91341
# Training until validation scores don't improve for 200 rounds
# Early stopping, best iteration is:
# [40]	training's rmse: 3.07982	valid_1's rmse: 1.8896
# Training until validation scores don't improve for 200 rounds
# Early stopping, best iteration is:
# [456]	training's rmse: 1.8555	valid_1's rmse: 2.08197
# Training until validation scores don't improve for 200 rounds
# Early stopping, best iteration is:
# [469]	training's rmse: 1.84662	valid_1's rmse: 1.53712

# %%
scores
# Out:
# [0.694944823486755,
#  0.4910364092794752,
#  0.5758286614769232,
#  1.043867531762851,
#  0.6407284882876945,
#  2.806485223328105,
#  2.806485223328105,
#  2.1635543094742546,
#  1.777591060614494,
#  1.6910521235899707,
#  1.7452791203501687,
#  1.9134084684488084,
#  1.8895994309434612,
#  2.08197349466302,
#  1.5371162937765075]

# %%
# 予測
test_x[y] = model.predict(test_x)

# %%
path = "../submission/"

submission = pd.read_csv(path + "sample_submission.csv", header=None)

submission.iloc[:,[1]] = pred
submission.head()
# Out:
#    0         1
# 0  0  1.598766
# 1  1  1.602905
# 2  2  1.598766
# 3  3  1.588539
# 4  4  1.588539

# %%
submission.to_csv(path + "submission.csv", index=False, header=None)
